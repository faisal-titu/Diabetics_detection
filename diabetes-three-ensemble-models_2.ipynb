# %% [markdown]
# <hr style="border: solid 3px blue;">
#
# # Introduction
#
# ![](https://upload.wikimedia.org/wikipedia/commons/6/6f/Pima.jpg)
#
# Picture Credit: https://upload.wikimedia.org
#
# **In this notebook, I would like to organize the following three ensemble models.**
# * Stacking Model
# * Soft Voting Model
# * Hard Voting Model
#
# After constructing and evaluating each model, we will select the optimal ensemble model to solve this problem.

# %% [markdown]
# Before we get started, let's take a quick look at datasets.
#
# **The objective of the dataset**
#
# > This dataset is originally from the National Institute of Diabetes and Digestive and Kidney Diseases. The objective of the dataset is to diagnostically predict whether or not a patient has diabetes, based on certain diagnostic measurements included in the dataset. Several constraints were placed on the selection of these instances from a larger database. In particular, all patients here are females at least 21 years old of Pima Indian heritage.
#
# **The Pima Indian Diabetes data set consists of:**
#
# * Pregnancies: Number of times pregnant
# * Glucose: Plasma glucose concentration a 2 hours in an oral glucose tolerance test
# * BloodPressure: Diastolic blood pressure (mm Hg)
# * SkinThickness: Triceps skin fold thickness (mm)
# * Insulin: 2-Hour serum insulin (mu U/ml)
# * BMI: Body mass index (weight in kg/(height in m)^2)
# * DiabetesPedigreeFunction: Diabetes pedigree function
# * Age: Age (years)
# * Outcome: Class variable (0 or 1) 268 of 768 are 1, the others are 0

# %%
# !pip install jinja2

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------
# # Load Libraries

# %%
# !pip uninstall numpy pandas -y
# !pip install numpy==1.26.4 pandas --no-binary :all:

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rcParams

from sklearn import model_selection
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score
from sklearn.metrics import f1_score, confusion_matrix, precision_recall_curve, roc_curve
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.preprocessing import StandardScaler


import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go

import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# # Defining Utility functions

# %%
def get_clf_eval(y_test, pred=None, pred_proba=None):
    confusion = confusion_matrix( y_test, pred)
    accuracy = accuracy_score(y_test , pred)
    precision = precision_score(y_test , pred)
    recall = recall_score(y_test , pred)
    f1 = f1_score(y_test,pred)   
     
    roc_auc = roc_auc_score(y_test, pred_proba)

    # ROC-AUC print 
    print('accuracy: {0:.4f}, precision: {1:.4f}, recall: {2:.4f},\
    F1: {3:.4f}, AUC:{4:.4f}'.format(accuracy, precision, recall, f1, roc_auc))
    return confusion

# %% [markdown]
# # Reading and Checking data

# %%
diabetes_df = pd.read_csv("archive/diabetes.csv")
diabetes_df.head().T.style.set_properties(**{'background-color': 'grey',
                           'color': 'white',
                           'border-color': 'white'})
# Out:
# <style type="text/css">
# #T_b0e7a_row0_col0, #T_b0e7a_row0_col1, #T_b0e7a_row0_col2, #T_b0e7a_row0_col3, #T_b0e7a_row0_col4, #T_b0e7a_row1_col0, #T_b0e7a_row1_col1, #T_b0e7a_row1_col2, #T_b0e7a_row1_col3, #T_b0e7a_row1_col4, #T_b0e7a_row2_col0, #T_b0e7a_row2_col1, #T_b0e7a_row2_col2, #T_b0e7a_row2_col3, #T_b0e7a_row2_col4, #T_b0e7a_row3_col0, #T_b0e7a_row3_col1, #T_b0e7a_row3_col2, #T_b0e7a_row3_col3, #T_b0e7a_row3_col4, #T_b0e7a_row4_col0, #T_b0e7a_row4_col1, #T_b0e7a_row4_col2, #T_b0e7a_row4_col3, #T_b0e7a_row4_col4, #T_b0e7a_row5_col0, #T_b0e7a_row5_col1, #T_b0e7a_row5_col2, #T_b0e7a_row5_col3, #T_b0e7a_row5_col4, #T_b0e7a_row6_col0, #T_b0e7a_row6_col1, #T_b0e7a_row6_col2, #T_b0e7a_row6_col3, #T_b0e7a_row6_col4, #T_b0e7a_row7_col0, #T_b0e7a_row7_col1, #T_b0e7a_row7_col2, #T_b0e7a_row7_col3, #T_b0e7a_row7_col4, #T_b0e7a_row8_col0, #T_b0e7a_row8_col1, #T_b0e7a_row8_col2, #T_b0e7a_row8_col3, #T_b0e7a_row8_col4 {
#   background-color: grey;
#   color: white;
#   border-color: white;
# }
# </style>
# <table id="T_b0e7a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b0e7a_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_b0e7a_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_b0e7a_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_b0e7a_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_b0e7a_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b0e7a_level0_row0" class="row_heading level0 row0" >Pregnancies</th>
#       <td id="T_b0e7a_row0_col0" class="data row0 col0" >6.000000</td>
#       <td id="T_b0e7a_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_b0e7a_row0_col2" class="data row0 col2" >8.000000</td>
#       <td id="T_b0e7a_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_b0e7a_row0_col4" class="data row0 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b0e7a_level0_row1" class="row_heading level0 row1" >Glucose</th>
#       <td id="T_b0e7a_row1_col0" class="data row1 col0" >148.000000</td>
#       <td id="T_b0e7a_row1_col1" class="data row1 col1" >85.000000</td>
#       <td id="T_b0e7a_row1_col2" class="data row1 col2" >183.000000</td>
#       <td id="T_b0e7a_row1_col3" class="data row1 col3" >89.000000</td>
#       <td id="T_b0e7a_row1_col4" class="data row1 col4" >137.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b0e7a_level0_row2" class="row_heading level0 row2" >BloodPressure</th>
#       <td id="T_b0e7a_row2_col0" class="data row2 col0" >72.000000</td>
#       <td id="T_b0e7a_row2_col1" class="data row2 col1" >66.000000</td>
#       <td id="T_b0e7a_row2_col2" class="data row2 col2" >64.000000</td>
#       <td id="T_b0e7a_row2_col3" class="data row2 col3" >66.000000</td>
#       <td id="T_b0e7a_row2_col4" class="data row2 col4" >40.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b0e7a_level0_row3" class="row_heading level0 row3" >SkinThickness</th>
#       <td id="T_b0e7a_row3_col0" class="data row3 col0" >35.000000</td>
#       <td id="T_b0e7a_row3_col1" class="data row3 col1" >29.000000</td>
#       <td id="T_b0e7a_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_b0e7a_row3_col3" class="data row3 col3" >23.000000</td>
#       <td id="T_b0e7a_row3_col4" class="data row3 col4" >35.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b0e7a_level0_row4" class="row_heading level0 row4" >Insulin</th>
#       <td id="T_b0e7a_row4_col0" class="data row4 col0" >0.000000</td>
#       <td id="T_b0e7a_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_b0e7a_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_b0e7a_row4_col3" class="data row4 col3" >94.000000</td>
#       <td id="T_b0e7a_row4_col4" class="data row4 col4" >168.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b0e7a_level0_row5" class="row_heading level0 row5" >BMI</th>
#       <td id="T_b0e7a_row5_col0" class="data row5 col0" >33.600000</td>
#       <td id="T_b0e7a_row5_col1" class="data row5 col1" >26.600000</td>
#       <td id="T_b0e7a_row5_col2" class="data row5 col2" >23.300000</td>
#       <td id="T_b0e7a_row5_col3" class="data row5 col3" >28.100000</td>
#       <td id="T_b0e7a_row5_col4" class="data row5 col4" >43.100000</td>
#     </tr>
#     <tr>
#       <th id="T_b0e7a_level0_row6" class="row_heading level0 row6" >DiabetesPedigreeFunction</th>
#       <td id="T_b0e7a_row6_col0" class="data row6 col0" >0.627000</td>
#       <td id="T_b0e7a_row6_col1" class="data row6 col1" >0.351000</td>
#       <td id="T_b0e7a_row6_col2" class="data row6 col2" >0.672000</td>
#       <td id="T_b0e7a_row6_col3" class="data row6 col3" >0.167000</td>
#       <td id="T_b0e7a_row6_col4" class="data row6 col4" >2.288000</td>
#     </tr>
#     <tr>
#       <th id="T_b0e7a_level0_row7" class="row_heading level0 row7" >Age</th>
#       <td id="T_b0e7a_row7_col0" class="data row7 col0" >50.000000</td>
#       <td id="T_b0e7a_row7_col1" class="data row7 col1" >31.000000</td>
#       <td id="T_b0e7a_row7_col2" class="data row7 col2" >32.000000</td>
#       <td id="T_b0e7a_row7_col3" class="data row7 col3" >21.000000</td>
#       <td id="T_b0e7a_row7_col4" class="data row7 col4" >33.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b0e7a_level0_row8" class="row_heading level0 row8" >Outcome</th>
#       <td id="T_b0e7a_row8_col0" class="data row8 col0" >1.000000</td>
#       <td id="T_b0e7a_row8_col1" class="data row8 col1" >0.000000</td>
#       <td id="T_b0e7a_row8_col2" class="data row8 col2" >1.000000</td>
#       <td id="T_b0e7a_row8_col3" class="data row8 col3" >0.000000</td>
#       <td id="T_b0e7a_row8_col4" class="data row8 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# DiabetesPedigreeFunction has a long name. Change to DPF.

# %%
diabetes_df.rename(columns ={"DiabetesPedigreeFunction":"DPF"},inplace=True)

# %% [markdown]
# --------------------------------------------
# # EDA

# %% [markdown]
# ## Checking Missing Values and Data type
# Let's check if there are missing values.

# %%
# !pip install missingno

# %%
import missingno as msno
msno.matrix(diabetes_df)
# Out:
# <Axes: >

# %% [markdown]
# **Good!. There is no missing value and all features type are number. Therefore, there is no need to preprocess for missing values.**

# %% [markdown]
# ## Checking Target Imbalance

# %%
# !pip install --upgrade nbformat

# %%
colors = ['gold', 'mediumturquoise']
labels = ['0','1']
values = diabetes_df['Outcome'].value_counts()/diabetes_df['Outcome'].shape[0]

# Use `hole` to create a donut-like pie chart
fig = go.Figure(data=[go.Pie(labels=labels, values=values, hole=.3)])
fig.update_traces(hoverinfo='label+percent', textinfo='percent', textfont_size=20,
                  marker=dict(colors=colors, line=dict(color='#000000', width=2)))
fig.update_layout(
    title_text="Outcome")
fig.show()

# %% [markdown]
# OK! The target is well balanced.

# %% [markdown]
# ## Checking Statistics

# %%
def highlight_min(s, props=''):
    return np.where(s == np.nanmin(s.values), props, '')

diabetes_df.describe().style.apply(highlight_min, props='color:Black;background-color:Grey', axis=0)
# Out:
# <style type="text/css">
# #T_932c6_row2_col7, #T_932c6_row3_col0, #T_932c6_row3_col1, #T_932c6_row3_col2, #T_932c6_row3_col3, #T_932c6_row3_col4, #T_932c6_row3_col5, #T_932c6_row3_col6, #T_932c6_row3_col8, #T_932c6_row4_col3, #T_932c6_row4_col4, #T_932c6_row4_col8, #T_932c6_row5_col8 {
#   color: Black;
#   background-color: Grey;
# }
# </style>
# <table id="T_932c6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_932c6_level0_col0" class="col_heading level0 col0" >Pregnancies</th>
#       <th id="T_932c6_level0_col1" class="col_heading level0 col1" >Glucose</th>
#       <th id="T_932c6_level0_col2" class="col_heading level0 col2" >BloodPressure</th>
#       <th id="T_932c6_level0_col3" class="col_heading level0 col3" >SkinThickness</th>
#       <th id="T_932c6_level0_col4" class="col_heading level0 col4" >Insulin</th>
#       <th id="T_932c6_level0_col5" class="col_heading level0 col5" >BMI</th>
#       <th id="T_932c6_level0_col6" class="col_heading level0 col6" >DPF</th>
#       <th id="T_932c6_level0_col7" class="col_heading level0 col7" >Age</th>
#       <th id="T_932c6_level0_col8" class="col_heading level0 col8" >Outcome</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_932c6_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_932c6_row0_col0" class="data row0 col0" >768.000000</td>
#       <td id="T_932c6_row0_col1" class="data row0 col1" >768.000000</td>
#       <td id="T_932c6_row0_col2" class="data row0 col2" >768.000000</td>
#       <td id="T_932c6_row0_col3" class="data row0 col3" >768.000000</td>
#       <td id="T_932c6_row0_col4" class="data row0 col4" >768.000000</td>
#       <td id="T_932c6_row0_col5" class="data row0 col5" >768.000000</td>
#       <td id="T_932c6_row0_col6" class="data row0 col6" >768.000000</td>
#       <td id="T_932c6_row0_col7" class="data row0 col7" >768.000000</td>
#       <td id="T_932c6_row0_col8" class="data row0 col8" >768.000000</td>
#     </tr>
#     <tr>
#       <th id="T_932c6_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_932c6_row1_col0" class="data row1 col0" >3.845052</td>
#       <td id="T_932c6_row1_col1" class="data row1 col1" >120.894531</td>
#       <td id="T_932c6_row1_col2" class="data row1 col2" >69.105469</td>
#       <td id="T_932c6_row1_col3" class="data row1 col3" >20.536458</td>
#       <td id="T_932c6_row1_col4" class="data row1 col4" >79.799479</td>
#       <td id="T_932c6_row1_col5" class="data row1 col5" >31.992578</td>
#       <td id="T_932c6_row1_col6" class="data row1 col6" >0.471876</td>
#       <td id="T_932c6_row1_col7" class="data row1 col7" >33.240885</td>
#       <td id="T_932c6_row1_col8" class="data row1 col8" >0.348958</td>
#     </tr>
#     <tr>
#       <th id="T_932c6_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T
>1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Among the features, there are many features whose min() value is 0. Let's check out more of these features.**

# %% [markdown]
# --------------------------------------------------
# # Checking and Removing Outliers

# %%
feature_names = [cname for cname in diabetes_df.loc[:,:'Age'].columns]

# %%
rcParams['figure.figsize'] = 40,60
sns.set(font_scale = 3)
sns.set_style("white")
sns.set_palette("bright")
plt.subplots_adjust(hspace=0.5)
i = 1;
for name in feature_names:
    plt.subplot(5,2,i)
    sns.histplot(data=diabetes_df, x=name, hue="Outcome",kde=True,palette="YlGnBu")
    i = i + 1

# %% [markdown]
# Looking at the pictures above, it would be good to change the zero value of each feature to another value.
# First, let's calculate the proportion of zero values in each feature.

# %%
zero_features = ['Pregnancies','Glucose','BloodPressure','SkinThickness',"Insulin",'BMI']
total_count = diabetes_df['Glucose'].count()

for feature in zero_features:
    zero_count = diabetes_df[diabetes_df[feature]==0][feature].count()
    print('{0} 0 number of cases {1}, percent is {2:.2f} %'.format(feature, zero_count, 100*zero_count/total_count))
# Out:
# Pregnancies 0 number of cases 111, percent is 14.45 %
# Glucose 0 number of cases 5, percent is 0.65 %
# BloodPressure 0 number of cases 35, percent is 4.56 %
# SkinThickness 0 number of cases 227, percent is 29.56 %
# Insulin 0 number of cases 374, percent is 48.70 %
# BMI 0 number of cases 11, percent is 1.43 %

# %% [markdown]
# As shown above, the ratio of the value of zero in the SkinThickness and Insulin features seems to be high. Let's change the corresponding values to the mean value of each feature.
#
# > However, a zero value may be meaningful to the corresponding feature. If you have an expert with expertise in diabetes, you will be able to confirm that your decision is correct.
# However, since there is no such domain knowledge or friends, we will first replace the corresponding value with the mean value.

# %%
diabetes_mean = diabetes_df[zero_features].mean()
diabetes_df[zero_features]=diabetes_df[zero_features].replace(0, diabetes_mean)

# %% [markdown]
# If we remove the zero value of each feature, we have a distribution similar to the normal distribution. Therefore, perform linear scaling and standard scaling.

# %%
X = diabetes_df.iloc[:,:-1]
y = diabetes_df.iloc[:,-1]

# %% [markdown]
# -------------------------------------------
# # Scaling
#
# Although the zero values of each feature are converted to mean values, some features have a one-sided shape. Therefore, we decided to perform nonlinear scaling, and decided to use the QuantileTransformer that changes the distribution closest to the normal distribution by referring to the notebook referenced below.
#
# > The quantile function ranks or smooths out the relationship between observations and can be mapped onto other distributions, such as the uniform or normal distribution.
#
# If you want to know more about Scaling, please refer to the notebook below.
#
# [Notebook](https://www.kaggle.com/ohseokkim/preprocessing-linear-nonlinear-scaling)

# %%
from sklearn.preprocessing import QuantileTransformer
scaler = QuantileTransformer(n_quantiles=100, random_state=0, output_distribution='normal')
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
def highlight_min(s, props=''):
    return np.where(s == np.nanmin(s.values), props, '')

X_train.describe().style.apply(highlight_min, props='color:Black;background-color:Grey', axis=0)
# Out:
# <style type="text/css">
# #T_de46a_row2_col1, #T_de46a_row2_col2, #T_de46a_row2_col5, #T_de46a_row2_col7, #T_de46a_row3_col0, #T_de46a_row3_col3, #T_de46a_row3_col4, #T_de46a_row3_col6 {
#   color: Black;
#   background-color: Grey;
# }
# </style>
# <table id="T_de46a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_de46a_level0_col0" class="col_heading level0 col0" >Pregnancies</th>
#       <th id="T_de46a_level0_col1" class="col_heading level0 col1" >Glucose</th>
#       <th id="T_de46a_level0_col2" class="col_heading level0 col2" >BloodPressure</th>
#       <th id="T_de46a_level0_col3" class="col_heading level0 col3" >SkinThickness</th>
#       <th id="T_de46a_level0_col4" class="col_heading level0 col4" >Insulin</th>
#       <th id="T_de46a_level0_col5" class="col_heading level0 col5" >BMI</th>
#       <th id="T_de46a_level0_col6" class="col_heading level0 col6" >DPF</th>
#       <th id="T_de46a_level0_col7" class="col_heading level0 col7" >Age</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_de46a_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_de46a_row0_col0" class="data row0 col0" >576.000000</td>
#       <td id="T_de46a_row0_col1" class="data row0 col1" >576.000000</td>
#       <td id="T_de46a_row0_col2" class="data row0 col2" >576.000000</td>
#       <td id="T_de46a_row0_col3" class="data row0 col3" >576.000000</td>
#       <td id="T_de46a_row0_col4" class="data row0 col4" >576.000000</td>
#       <td id="T_de46a_row0_col5" class="data row0 col5" >576.000000</td>
#       <td id="T_de46a_row0_col6" class="data row0 col6" >576.000000</td>
#       <td id="T_de46a_row0_col7" class="data row0 col7" >576.000000</td>
#     </tr>
#     <tr>
#       <th id="T_de46a_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_de46a_row1_col0" class="data row1 col0" >4.315407</td>
#       <td id="T_de46a_row1_col1" class="data row1 col1" >121.709154</td>
#       <td id="T_de46a_row1_col2" class="data row1 col2" >72.144653</td>
#       <td id="T_de46a_row1_col3" class="data row1 col3" >26.341978</td>
#       <td id="T_de46a_row1_col4" class="data row1 col4" >118.600098</td>
#       <td id="T_de46a_row1_col5" class="data row1 col5" >32.315027</td>
#       <td id="T_de46a_row1_col6" class="data row1 col6" >0.468618</td>
#       <td id="T_de46a_row1_col7" class="data row1 col7" >32.921875</td>
#     </tr>
#     <tr>
#       <th id="T_de46a_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_de46a_row2_col0" class="data row2 col0" >2.916151</td>
#       <td id="T_de46a_row2_col1" class="data row2 col1" >30.080570</td>
#       <td id="T_de46a_row2_col2" class="data row2 col2" >12.113756</td>
#       <td id="T_de46a_row2_col3" class="data row2 col3" >9.158041</td>
#       <td id="T_de46a_row2_col4" class="data row2 col4" >94.570101</td>
#       <td id="T_de46a_row2_col5" class="data row2 col5" >6.878494</td>
#       <td id="T_de46a_row2_col6" class="data row2 col6" >0.339325</td>
#       <td id="T_de46a_row2_col7" class="data row2 col7" >11.507539</td>
#     </tr>
#     <tr>
#       <th id="T_de46a_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_de46a_row3_col0" class="data row3 col0" >1.000000</td>
#       <td id="T_de46a_row3_col1" class="data row3 col1" >44.000000</td>
#       <td id="T_de46a_row3_col2" class="data row3 col2" >24.000000</td>
#       <td id="T_de46a_row3_col3" class="data row3 col3" >8.000000</td>
#       <td id="T_de46a_row3_col4" class="data row3 col4" >14.000000</td>
#       <td id="T_de46a_row3_col5" class="data row3 col5" >18.200000</td>
#       <td id="T_de46a_row3_col6" class="data row3 col6" >0.078000</td>
#       <td id="T_de46a_row3_col7" class="data row3 col7" >21.000000</td>
#     </tr>
#     <tr>
#       <th id="T_de46a_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_de46a_row4_col0" class="data row4 col0" >2.000000</td>
#       <td id="T_de46a_row4_col1" class="data row4 col1" >100.000000</td>
#       <td id="T_de46a_row4_col2" class="data row4 col2" >64.000000</td>
#       <td id="T_de46a_row4_col3" class="data row4 col3" >20.536458</td>
#       <td id="T_de46a_row4_col4" class="data row4 col4" >79.799479</td>
#       <td id="T_de46a_row4_col5" class="data row4 col5" >27.275000</td>
#       <td id="T_de46a_row4_col6" class="data row4 col6" >0.240000</td>
#       <td id="T_de46a_row4_col7" class="data row4 col7" >24.000000</td>
#     </tr>
#     <tr>
#       <th id="T_de46a_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_de46a_row5_col0" class="data row5 col0" >3.845052</td>
#       <td id="T_de46a_row5_col1" class="data row5 col1" >118.000000</td>
#       <td id="T_de46a_row5_col2" class="data row5 col2" >72.000000</td>
#       <td id="T_de46a_row5_col3" class="data row5 col3" >23.000000</td>
#       <td id="T_de46a_row5_col4" class="data row5 col4" >79.799479</td>
#       <td id="T_de46a_row5_col5" class="data row5 col5" >32.000000</td>
#       <td id="T_de46a_row5_col6" class="data row5 col6" >0.372500</td>
#       <td id="T_de46a_row5_col7" class="data row5 col7" >29.000000</td>
#     </tr>
#     <tr>
#       <th id="T_de46a_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_de46a_row6_col0" class="data row6 col0" >6.000000</td>
#       <td id="T_de46a_row6_col1" class="data row6 col1" >138.250000</td>
#       <td id="T_de46a_row6_col2" class="data row6 col2" >80.000000</td>
#       <td id="T_de46a_row6_col3" class="data row6 col3" >32.000000</td>
#       <td id="T_de46a_row6_col4" class="data row6 col4" >127.500000</td>
#       <td id="T_de46a_row6_col5" class="data row6 col5" >36.325000</td>
#       <td id="T_de46a_row6_col6" class="data row6 col6" >0.612250</td>
#       <td id="T_de46a_row6_col7" class="data row6 col7" >40.000000</td>
#     </tr>
#     <tr>
#       <th id="T_de46a_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_de46a_row7_col0" class="data row7 col0" >17.000000</td>
#       <td id="T_de46a_row7_col1" class="data row7 col1" >199.000000</td>
#       <td id="T_de46a_row7_col2" class="data row7 col2" >122.000000</td>
#       <td id="T_de46a_row7_col3" class="data row7 col3" >63.000000</td>
#       <td id="T_de46a_row7_col4" class="data row7 col4" >846.000000</td>
#       <td id="T_de46a_row7_col5" class="data row7 col5" >67.100000</td>
#       <td id="T_de46a_row7_col6" class="data row7 col6" >2.420000</td>
#       <td id="T_de46a_row7_col7" class="data row7 col7" >81.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
rcParams['figure.figsize'] = 40,60
sns.set(font_scale = 3)
sns.set_style("white")
sns.set_palette("bright")
plt.subplots_adjust(hspace=0.5)
i = 1;
for name in feature_names:
    plt.subplot(5,2,i)
    sns.histplot(data=diabetes_df, x=name, hue="Outcome",kde=True,palette="YlGnBu")
    i = i + 1

# %% [markdown]
# Looking at the picture above, you can see that the zero value is removed and scaling is done. However, the shape of the distribution of Pregnancies does not look good.

# %% [markdown]
# # Checking correlation between features
#
# Let's check the correlations between each variable.

# %%
corr=diabetes_df.corr().round(2)

sns.set(font_scale=1.15)
plt.figure(figsize=(14, 10))
sns.set_palette("bright")
sns.set_style("white")
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(corr,annot=True,cmap='gist_yarg_r',mask=mask,cbar=True)
plt.title('Correlation Plot')
# Out:
# Text(0.5, 1.0, 'Correlation Plot')

# %%
sns.set(font_scale=2)
plt.figure(figsize=(10, 8))
sns.set_style("white")
sns.set_palette("bright")
sns.pairplot(diabetes_df,kind = 'reg',corner = True,palette ='YlGnBu' )

# %% [markdown]
# <span style="color:Blue"> **Observation:**
# * The correlation between Outcome and Glucose is high. Glucoe seems to be the most important feature in model training.
# * BMI, Pregnancys, and Age are also expected to be used as important features in model training.
# * High correlation coefficient with SkinThickness and BMI. There may be a multicollinearity problem, but if there is a performance problem after checking the result, check it again.

# %% [markdown]
# -----------------------------------------------
# # Checking features before modeling

# %% [markdown]
# Looking at the figure above, the correlation coefficient between Outcome and Glucose is the highest at 0.49. Let's examine this in more depth.

# %%
fig = px.histogram(diabetes_df, x="Glucose", 
                   color="Outcome", 
                   marginal="box",
                   barmode ="overlay",
                   histnorm ='density'
                  )  
fig.update_layout(
    title_font_color="black",
    legend_title_font_color="green",
    title={
        'text': "Glucose Histogram per Outcome",
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'},
)
fig.show()

# %%
import plotly.express as px
fig = px.histogram(diabetes_df, x="BMI", 
                   color="Outcome", 
                   marginal="box",
                   barmode ="overlay",
                   histnorm ='density'
                  )  
fig.update_layout(
    title_font_color="black",
    legend_title_font_color="green",
    title={
        'text': "BMI Histogram per Outcome",
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'},
)
fig.show()

# %%
import plotly.express as px
fig = px.histogram(diabetes_df, x="Age", 
                   color="Outcome", 
                   marginal="box",
                   barmode ="overlay",
                   histnorm ='density'
                  )  
fig.update_layout(
    title_font_color="black",
    legend_title_font_color="green",
    title={
        'text': "Age Histogram per Outcome",
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'},
)
fig.show()

# %% [markdown]
# From the above figures, you can see what distribution each feature has for each output. In the case of glucose with high correlation, it can be seen that the distribution of outcomes 1 and 0 has a more distant shape than other features. In this case, it is expected to have a better effect on classification.

# %% [markdown]
# **OK! Let's make models and train it.**

# %% [markdown]
# ----------------------------------------------------------------------------
# # Visualizing Training Dataset after Dimension Reduction

# %%
X_train = diabetes_df.drop('Outcome',axis=1)
y_train = diabetes_df['Outcome']

# %% [markdown]
# ## 2D plot

# %%
# !pip install pandas matplotlib datashader bokeh holoviews scikit-image colorcet

# %%
import umap
import umap.plot

mapper = umap.UMAP().fit(X_train) 
umap.plot.points(mapper, labels=y_train, theme='fire')
# Out:
# <Axes: >

# %% [markdown]
# The 8-dimensional training dataset shown in the figure above is drawn by reducing the dimensions to 2D. As you can see in the figure, positive and negative are overlapped at the bottom of the figure. Since our models are mainly tree-based models, we will mainly work on determining the boundary, but it seems to be a difficult task in 2D.
#
# However, our training dataset is 8-dimensional, just that we can't visualize it. Therefore, it will not be a very difficult task for our models to determine the boundary as shown above.

# %% [markdown]
# ## 3D plot

# %%
from umap import UMAP

umap_3d = UMAP(n_components=3, init='random', random_state=0)
x_umap = umap_3d.fit_transform(X_train)
umap_df = pd.DataFrame(x_umap)
train_y_sr = pd.Series(y_train,name='label').astype(str)
print(type(x_umap))
new_df = pd.concat([umap_df,train_y_sr],axis=1)
fig = px.scatter_3d(
    new_df, x=0, y=1, z=2,
    color='label', labels={'color': 'number'}
)
fig.update_traces(marker_size=1.5)
fig.show()
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# Even if you increase the dimension to 3D, you can see overlapping points. We want to see it from a higher dimension, but we can't draw.
#
# **Now, all we have to do is do some good modeling and fine tune the hyperparameters.**

# %% [markdown]
# <hr style="border: solid 3px blue;">
#
# # Ensemble
#
# ![](https://miro.medium.com/max/637/1*3GIDYOn2GNcv9bq4bQk5YA.jpeg)
#
# Picture Credit: https://miro.medium.com
#
# > Supervised learning algorithms perform the task of searching through a hypothesis space to find a suitable hypothesis that will make good predictions with a particular problem.Even if the hypothesis space contains hypotheses that are very well-suited for a particular problem, it may be very difficult to find a good one. Ensembles combine multiple hypotheses to form a (hopefully) better hypothesis. The term ensemble is usually reserved for methods that generate multiple hypotheses using the same base learner. The broader term of multiple classifier systems also covers hybridization of hypotheses that are not induced by the same base learner.
#
# Ref: https://en.wikipedia.org/wiki/Ensemble_learning

# %%
# !pip install pycaret
# !pip install scikit-learn==1.4.2 --force-reinstall

# %%
from pycaret.classification import *

# %% [markdown]
# ## Setup
#
# > This function initializes the training environment and creates the transformation pipeline. Setup function must be called before executing any other function. It takes two mandatory parameters: data and target. All the other parameters are optional.
#
# Ref: https://pycaret.readthedocs.io/en/latest/api/classification.html

# %%
clf1 = setup(data = diabetes_df, 
             target = 'Outcome',
             preprocess = False,
             verbose= False)

# %% [markdown]
# ## Comparing Models
#
# > This function trains and evaluates performance of all estimators available in the model library using cross validation. The output of this function is a score grid with average cross validated scores.
#
# Ref: https://pycaret.readthedocs.io/en/latest/api/classification.html

# %%
top5 = compare_models(sort='AUC',
                      n_select = 5,
                      exclude=['lightgbm','xgboost','dummy','svm','ridge','knn','dt','nb','qda']
                     )
# Out:
# <style type="text/css">
# #T_0da7b th {
#   text-align: left;
# }
# #T_0da7b_row0_col0, #T_0da7b_row0_col1, #T_0da7b_row0_col3, #T_0da7b_row0_col4, #T_0da7b_row0_col5, #T_0da7b_row0_col6, #T_0da7b_row0_col7, #T_0da7b_row1_col0, #T_0da7b_row1_col1, #T_0da7b_row1_col2, #T_0da7b_row1_col3, #T_0da7b_row1_col5, #T_0da7b_row1_col6, #T_0da7b_row1_col7, #T_0da7b_row2_col0, #T_0da7b_row2_col1, #T_0da7b_row2_col2, #T_0da7b_row2_col3, #T_0da7b_row2_col4, #T_0da7b_row2_col5, #T_0da7b_row2_col6, #T_0da7b_row2_col7, #T_0da7b_row3_col0, #T_0da7b_row3_col1, #T_0da7b_row3_col2, #T_0da7b_row3_col3, #T_0da7b_row3_col4, #T_0da7b_row3_col5, #T_0da7b_row3_col6, #T_0da7b_row3_col7, #T_0da7b_row4_col0, #T_0da7b_row4_col2, #T_0da7b_row4_col4, #T_0da7b_row5_col0, #T_0da7b_row5_col1, #T_0da7b_row5_col2, #T_0da7b_row5_col3, #T_0da7b_row5_col4, #T_0da7b_row5_col5, #T_0da7b_row5_col6, #T_0da7b_row5_col7, #T_0da7b_row6_col0, #T_0da7b_row6_col1, #T_0da7b_row6_col2, #T_0da7b_row6_col3, #T_0da7b_row6_col4, #T_0da7b_row6_col5, #T_0da7b_row6_col6, #T_0da7b_row6_col7 {
#   text-align: left;
# }
# #T_0da7b_row0_col2, #T_0da7b_row1_col4, #T_0da7b_row4_col1, #T_0da7b_row4_col3, #T_0da7b_row4_col5, #T_0da7b_row4_col6, #T_0da7b_row4_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_0da7b_row0_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# #T_0da7b_row1_col8, #T_0da7b_row2_col8, #T_0da7b_row3_col8, #T_0da7b_row4_col8, #T_0da7b_row5_col8, #T_0da7b_row6_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_0da7b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0da7b_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_0da7b_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_0da7b_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_0da7b_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_0da7b_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_0da7b_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_0da7b_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_0da7b_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_0da7b_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0da7b_level0_row0" class="row_heading level0 row0" >lda</th>
#       <td id="T_0da7b_row0_col0" class="data row0 col0" >Linear Discriminant Analysis</td>
#       <td id="T_0da7b_row0_col1" class="data row0 col1" >0.7841</td>
#       <td id="T_0da7b_row0_col2" class="data row0 col2" >0.8476</td>
#       <td id="T_0da7b_row0_col3" class="data row0 col3" >0.6000</td>
#       <td id="T_0da7b_row0_col4" class="data row0 col4" >0.7341</td>
#       <td id="T_0da7b_row0_col5" class="data row0 col5" >0.6568</td>
#       <td id="T_0da7b_row0_col6" class="data row0 col6" >0.5026</td>
#       <td id="T_0da7b_row0_col7" class="data row0 col7" >0.5104</td>
#       <td id="T_0da7b_row0_col8" class="data row0 col8" >0.0100</td>
#     </tr>
#     <tr>
#       <th id="T_0da7b_level0_row1" class="row_heading level0 row1" >lr</th>
#       <td id="T_0da7b_row1_col0" class="data row1 col0" >Logistic Regression</td>
#       <td id="T_0da7b_row1_col1" class="data row1 col1" >0.7878</td>
#       <td id="T_0da7b_row1_col2" class="data row1 col2" >0.8475</td>
#       <td id="T_0da7b_row1_col3" class="data row1 col3" >0.6053</td>
#       <td id="T_0da7b_row1_col4" class="data row1 col4" >0.7401</td>
#       <td id="T_0da7b_row1_col5" class="data row1 col5" >0.6625</td>
#       <td id="T_0da7b_row1_col6" class="data row1 col6" >0.5111</td>
#       <td id="T_0da7b_row1_col7" class="data row1 col7" >0.5188</td>
#       <td id="T_0da7b_row1_col8" class="data row1 col8" >0.7370</td>
#     </tr>
#     <tr>
#       <th id="T_0da7b_level0_row2" class="row_heading level0 row2" >catboost</th>
#       <td id="T_0da7b_row2_col0" class="data row2 col0" >CatBoost Classifier</td>
#       <td id="T_0da7b_row6_col2" class="data row6 col2" >0.8226</td>
#       <td id="T_0da7b_row6_col3" class="data row6 col3" >0.6494</td>
#       <td id="T_0da7b_row6_col4" class="data row6 col4" >0.6710</td>
#       <td id="T_0da7b_row6_col5" class="data row6 col5" >0.6547</td>
#       <td id="T_0da7b_row6_col6" class="data row6 col6" >0.4834</td>
#       <td id="T_0da7b_row6_col7" class="data row6 col7" >0.4876</td>
#       <td id="T_0da7b_row6_col8" class="data row6 col8" >0.0330</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Creating Models
#
# > This function trains and evaluates the performance of a given estimator using cross validation. The output of this function is a score grid with CV scores by fold.
#
# Ref: https://pycaret.readthedocs.io/en/latest/api/classification.html

# %%
from pycaret.classification import models
print(models())
# Out:
#                                      Name  \
# ID
# lr                    Logistic Regression
# knn                K Neighbors Classifier
# nb                            Naive Bayes
# dt               Decision Tree Classifier
# svm                   SVM - Linear Kernel
# rbfsvm                SVM - Radial Kernel
# gpc           Gaussian Process Classifier
# mlp                        MLP Classifier
# ridge                    Ridge Classifier
# rf               Random Forest Classifier
# qda       Quadratic Discriminant Analysis
# ada                  Ada Boost Classifier
# gbc          Gradient Boosting Classifier
# lda          Linear Discriminant Analysis
# et                 Extra Trees Classifier
# lightgbm  Light Gradient Boosting Machine
# catboost              CatBoost Classifier
# dummy                    Dummy Classifier
#
#                                                   Reference  Turbo
# ID
# lr        sklearn.linear_model._logistic.LogisticRegression   True
# knn       sklearn.neighbors._classification.KNeighborsCl...   True
# nb                           sklearn.naive_bayes.GaussianNB   True
# dt             sklearn.tree._classes.DecisionTreeClassifier   True
# svm       sklearn.linear_model._stochastic_gradient.SGDC...   True
# rbfsvm                             sklearn.svm._classes.SVC  False
# gpc       sklearn.gaussian_process._gpc.GaussianProcessC...  False
# mlp       sklearn.neural_network._multilayer_perceptron....  False
# ridge           sklearn.linear_model._ridge.RidgeClassifier   True
# rf          sklearn.ensemble._forest.RandomForestClassifier   True
# qda       sklearn.discriminant_analysis.QuadraticDiscrim...   True
# ada       sklearn.ensemble._weight_boosting.AdaBoostClas...   True
# gbc         sklearn.ensemble._gb.GradientBoostingClassifier   True
# lda       sklearn.discriminant_analysis.LinearDiscrimina...   True
# et            sklearn.ensemble._forest.ExtraTreesClassifier   True
# lightgbm                    lightgbm.sklearn.LGBMClassifier   True
# catboost                   catboost.core.CatBoostClassifier   True
# dummy                         sklearn.dummy.DummyClassifier   True

# %%
catboost = create_model('catboost')
rf = create_model('rf')
lr = create_model('lr')
lda = create_model('lda')
gbc = create_model('gbc')
# Out:
# <style type="text/css">
# #T_6d6af_row10_col0, #T_6d6af_row10_col1, #T_6d6af_row10_col2, #T_6d6af_row10_col3, #T_6d6af_row10_col4, #T_6d6af_row10_col5, #T_6d6af_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_6d6af">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6d6af_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_6d6af_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_6d6af_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_6d6af_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_6d6af_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_6d6af_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_6d6af_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6d6af_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6d6af_row0_col0" class="data row0 col0" >0.7407</td>
#       <td id="T_6d6af_row0_col1" class="data row0 col1" >0.8406</td>
#       <td id="T_6d6af_row0_col2" class="data row0 col2" >0.5263</td>
#       <td id="T_6d6af_row0_col3" class="data row0 col3" >0.6667</td>
#       <td id="T_6d6af_row0_col4" class="data row0 col4" >0.5882</td>
#       <td id="T_6d6af_row0_col5" class="data row0 col5" >0.4028</td>
#       <td id="T_6d6af_row0_col6" class="data row0 col6" >0.4088</td>
#     </tr>
#     <tr>
#       <th id="T_6d6af_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_
level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6d6af_row6_col0" class="data row6 col0" >0.7963</td>
#       <td id="T_6d6af_row6_col1" class="data row6 col1" >0.8556</td>
#       <td id="T_6d6af_row6_col2" class="data row6 col2" >0.6316</td>
#       <td id="T_6d6af_row6_col3" class="data row6 col3" >0.7500</td>
#       <td id="T_6d6af_row6_col4" class="data row6 col4" >0.6857</td>
#       <td id="T_6d6af_row6_col5" class="data row6 col5" >0.5367</td>
#       <td id="T_6d6af_row6_col6" class="data row6 col6" >0.5410</td>
#     </tr>
#     <tr>
#       <th id="T_6d6af_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6d6af_row7_col0" class="data row7 col0" >0.8491</td>
#       <td id="T_6d6af_row7_col1" class="data row7 col1" >0.8778</td>
#       <td id="T_6d6af_row7_col2" class="data row7 col2" >0.8333</td>
#       <td id="T_6d6af_row7_col3" class="data row7 col3" >0.7500</td>
#       <td id="T_6d6af_row7_col4" class="data row7 col4" >0.7895</td>
#       <td id="T_6d6af_row7_col5" class="data row7 col5" >0.6723</td>
#       <td id="T_6d6af_row7_col6" class="data row7 col6" >0.6746</td>
#     </tr>
#     <tr>
#       <th id="T_6d6af_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6d6af_row8_col0" class="data row8 col0" >0.7925</td>
#       <td id="T_6d6af_row8_col1" class="data row8 col1" >0.8905</td>
#       <td id="T_6d6af_row8_col2" class="data row8 col2" >0.6667</td>
#       <td id="T_6d6af_row8_col3" class="data row8 col3" >0.7059</td>
#       <td id="T_6d6af_row8_col4" class="data row8 col4" >0.6857</td>
#       <td id="T_6d6af_row8_col5" class="data row8 col5" >0.5310</td>
#       <td id="T_6d6af_row8_col6" class="data row8 col6" >0.5315</td>
#     </tr>
#     <tr>
#       <th id="T_6d6af_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6d6af_row9_col0" class="data row9 col0" >0.7925</td>
#       <td id="T_6d6af_row9_col1" class="data row9 col1" >0.8270</td>
#       <td id="T_6d6af_row9_col2" class="data row9 col2" >0.8333</td>
#       <td id="T_6d6af_row9_col3" class="data row9 col3" >0.6522</td>
#       <td id="T_6d6af_row9_col4" class="data row9 col4" >0.7317</td>
#       <td id="T_6d6af_row9_col5" class="data row9 col5" >0.5665</td>
#       <td id="T_6d6af_row9_col6" class="data row9 col6" >0.5779</td>
#     </tr>
#     <tr>
#       <th id="T_6d6af_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_6d6af_row10_col0" class="data row10 col0" >0.7823</td>
#       <td id="T_6d6af_row10_col1" class="data row10 col1" >0.8467</td>
#       <td id="T_6d6af_row10_col2" class="data row10 col2" >0.6491</td>
#       <td id="T_6d6af_row10_col3" class="data row10 col3" >0.7046</td>
#       <td id="T_6d6af_row10_col4" class="data row10 col4" >0.6703</td>
#       <td id="T_6d6af_row10_col5" class="data row10 col5" >0.5095</td>
#       <td id="T_6d6af_row10_col6" class="data row10 col6" >0.5150</td>
#     </tr>
#     <tr>
#       <th id="T_6d6af_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_6d6af_row11_col0" class="data row11 col0" >0.0538</td>
#       <td id="T_6d6af_row11_col1" class="data row11 col1" >0.0458</td>
#       <td id="T_6d6af_row11_col2" class="data row11 col2" >0.1329</td>
#       <td id="T_6d6af_row11_col3" class="data row11 col3" >0.0802</td>
#       <td id="T_6d6af_row11_col4
# <style type="text/css">
# #T_237a3_row10_col0, #T_237a3_row10_col1, #T_237a3_row10_col2, #T_237a3_row10_col3, #T_237a3_row10_col4, #T_237a3_row10_col5, #T_237a3_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_237a3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_237a3_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_237a3_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_237a3_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_237a3_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_237a3_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_237a3_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_237a3_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_237a3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_237a3_row0_col0" class="data row0 col0" >0.7963</td>
#       <td id="T_237a3_row0_col1" class="data row0 col1" >0.8481</td>
#       <td id="T_237a3_row0_col2" class="data row0 col2" >0.7368</td>
#       <td id="T_237a3_row0_col3" class="data row0 col3" >0.7000</td>
#       <td id="T_237a3_row0_col4" class="data row0 col4" >0.7179</td>
#       <td id="T_237a3_row0_col5" class="data row0 col5" >0.5587</td>
#       <td id="T_237a3_row0_col6" class="data row0 col6" >0.5591</td>
#     </tr>
#     <tr>
#       <th id="T_237a3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_237a3_row1_col0" class="data row1 col0" >0.7222</td>
#       <td id="T_237a3_row1_col1" class="data row1 col1" >0.7481</td>
#       <td id="T_237a3_row1_col2" class="data row1 col2" >0.5789</td>
#       <td id="T_237a3_row1_col3" class="data row1 col3" >0.6111</td>
#       <td id="T_237a3_row1_col4" class="data row1 col4" >0.5946</td>
#       <td id="T_237a3_row1_col5" class="data row1 col5" >0.3836</td>
#       <td id="T_237a3_row1_col6" class="data row1 col6" >0.3839</td>
#     </tr>
#     <tr>
#       <th id="T_237a3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_237a3_row2_col0" class="data row2 col0" >0.8519</td>
#       <td id="T_237a3_row2_col1" class="data row2 col1" >0.9135</td>
#       <td id="T_237a3_row2_col2" class="data row2 col2" >0.8421</td>
#       <td id="T_237a3_row2_col3" class="data row2 col3" >0.7619</td>
#       <td id="T_237a3_row2_col4" class="data row2 col4" >0.8000</td>
#       <td id="T_237a3_row2_col5" class="data row2 col5" >0.6828</td>
#       <td id="T_237a3_row2_col6" class="data row2 col6" >0.6850</td>
#     </tr>
#     <tr>
#       <th id="T_237a3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_237a3_row3_col0" class="data row3 col0" >0.7222</td>
#       <td id="T_237a3_row3_col1" class="data row3 col1" >0.7797</td>
#       <td id="T_237a3_row3_col2" class="data row3 col2" >0.5263</td>
#       <td id="T_237a3_row3_col3" class="data row3 col3" >0.6250</td>
#       <td id="T_237a3_row3_col4" class="data row3 col4" >0.5714</td>
#       <td id="T_237a3_row3_col5" class="data row3 col5" >0.3682</td>
#       <td id="T_237a3_row3_col6" class="data row3 col6" >0.3711</td>
#     </tr>
#     <tr>
#       <th id="T_237a3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_237a3_row4_col0" class="data row4 col0" >0.7593</td>
#       <td id="T_237a3_row4_col1" class="data row4 col1" >0.7835</td>
#       <td id="T_237a3_row4_col2" class="data row4 col2" >0.5263</td>
#       <td id="T_237a3_row4_col3" class="data row4 col3" >0.7143</td>
#       <td id="T_237a3_row4_col4" class="data row4 col4" >0.6061</td>
#       <td id="T_237a3_row4_col5" class="data row4 col5" >0.4384</td>
#       <td id="T_237a3_row4_col6" class="data row4 col6" >0.4490</td>
#     </tr>
#     <tr>
#       <th id="T_237a3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_237a3_row5_col0" class="data row5 col0" >0.8148</td>
#       <td id="T_237a3_row5_col1" class="data row5 col1" >0.8609</td>
#       <td id="T_237a3_row5_col2" class="data row5 col2" >0.5789</td>
#       <td id="T_237a3_row5_col3" class="data row5 col3" >0.8462</td>
#       <td id="T_237a3_row5_col4" class="data row5 col4" >0.6875</td>
#       <td id="T_237a3_row5_col5" class="data row5 col5" >0.5624</td>
#       <td id="T_237a3_row5_col6" class="data row5 col6" >0.5828</td>
#     </tr>
#     <tr>
#       <th id="T_237a3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_237a3_row6_col0" class="data row6 col0" >0.7963</td>
#       <td id="T_237a3_row6_col1" class="data row6 col1" >0.8511</td>
#       <td id="T_237a3_row6_col2" class="data row6 col2" >0.5263</td>
#       <td id="T_237a3_row6_col3" class="data row6 col3" >0.8333</td>
#       <td id="T_237a3_row6_col4" class="data row6 col4" >0.6452</td>
#       <td id="T_237a3_row6_col5" class="data row6 col5" >0.5123</td>
#       <td id="T_237a3_row6_col6" class="data row6 col6" >0.5389</td>
#     </tr>
#     <tr>
#       <th id="T_237a3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_237a3_row7_col0" class="data row7 col0" >0.8491</td>
#       <td id="T_237a3_row7_col1" class="data row7 col1" >0.8659</td>
#       <td id="T_237a3_row7_col2" class="data row7 col2" >0.7778</td>
#       <td id="T_237a3_row7_col3" class="data row7 col3" >0.7778</td>
#       <td id="T_237a3_row7_col4" class="data row7 col4" >0.7778</td>
#       <td id="T_237a3_row7_col5" class="data row7 col5" >0.6635</td>
#       <td id="T_237a3_row7_col6" class="data row7 col6" >0.6635</td>
#     </tr>
#     <tr>
#       <th id="T_237a3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_237a3_row8_col0" class="data row8 col0" >0.8302</td>
#       <td id="T_237a3_row8_col1" class="data row8 col1" >0.8770</td>
#       <td id="T_237a3_row8_col2" class="data row8 col2" >0.7222</td>
#       <td id="T_237a3_row8_col3" class="data row8 col3" >0.7647</td>
#       <td id="T_237a3_row8_col4" class="data row8 col4" >0.7429</td>
#       <td id="T_237a3_row8_col5" class="data row8 col5" >0.6163</td>
#       <td id="T_237a3_row8_col6" class="data row8 col6" >0.6168</td>
#     </tr>
#     <tr>
#       <th id="T_237a3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_237a3_row9_col0" class="data row9 col0" >0.7925</td>
#       <td id="T_237a3_row9_col1" class="data row9 col1" >0.8262</td>
#       <td id="T_237a3_row9_col2" class="data row9 col2" >0.7778</td>
#       <td id="T_237a3_row9_col3" class="data row9 col3" >0.6667</td>
#       <td id="T_237a3_row9_col4" class="data row9 col4" >0.7179</td>
#       <td id="T_237a3_row9_col5" class="data row9 col5" >0.5553</td>
#       <td id="T_237a3_row9_col6" class="data row9 col6" >0.5594</td>
#     </tr>
#     <tr>
#       <th id="T_237a3_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_237a3_row10_col0" class="data row10 col0" >0.7935</td>
#       <td id="T_237a3_row10_col1" class="data row10 col1" >0.8354</td>
#       <td id="T_237a3_row10_col2" class="data row10 col2" >0.6594</td>
#       <td id="T_237a3_row10_col3" class="data row10 col3" >0.7301</td>
#       <td id="T_237a3_row10_col4" class="data row10 col4" >0.6861</td>
#       <td id="T_237a3_row10_col5" class="data row10 col5" >0.5341</td>
#       <td id="T_237a3_row10_col6" class="data row10 col6" >0.5410</td>
#     </tr>
#     <tr>
#       <th id="T_237a3_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T
_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2643d_row4_col0" class="data row4 col0" >0.7963</td>
#       <td id="T_2643d_row4_col1" class="data row4 col1" >0.8541</td>
#       <td id="T_2643d_row4_col2" class="data row4 col2" >0.5789</td>
#       <td id="T_2643d_row4_col3" class="data row4 col3" >0.7857</td>
#       <td id="T_2643d_row4_col4" class="data row4 col4" >0.6667</td>
#       <td id="T_2643d_row4_col5" class="data row4 col5" >0.5248</td>
#       <td id="T_2643d_row4_col6" class="data row4 col6" >0.5375</td>
#     </tr>
#     <tr>
#       <th id="T_2643d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2643d_row5_col0" class="data row5 col0" >0.7778</td>
#       <td id="T_2643d_row5_col1" class="data row5 col1" >0.8361</td>
#       <td id="T_2643d_row5_col2" class="data row5 col2" >0.5263</td>
#       <td id="T_2643d_row5_col3" class="data row5 col3" >0.7692</td>
#       <td id="T_2643d_row5_col4" class="data row5 col4" >0.6250</td>
#       <td id="T_2643d_row5_col5" class="data row5 col5" >0.4749</td>
#       <td id="T_2643d_row5_col6" class="data row5 col6" >0.4921</td>
#     </tr>
#     <tr>
#       <th id="T_2643d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2643d_row6_col0" class="data row6 col0" >0.7778</td>
#       <td id="T_2643d_row6_col1" class="data row6 col1" >0.8662</td>
#       <td id="T_2643d_row6_col2" class="data row6 col2" >0.5263</td>
#       <td id="T_2643d_row6_col3" class="data row6 col3" >0.7692</td>
#       <td id="T_2643d_row6_col4" class="data row6 col4" >0.6250</td>
#       <td id="T_2643d_row6_col5" class="data row6 col5" >0.4749</td>
#       <td id="T_2643d_row6_col6" class="data row6 col6" >0.4921</td>
#     </tr>
#     <tr>
#       <th id="T_2643d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2643d_row7_col0" class="data row7 col0" >0.8302</td>
#       <td id="T_2643d_row7_col1" class="data row7 col1" >0.8571</td>
#       <td id="T_2643d_row7_col2" class="data row7 col2" >0.7222</td>
#       <td id="T_2643d_row7_col3" class="data row7 col3" >0.7647</td>
#       <td id="T_2643d_row7_col4" class="data row7 col4" >0.7429</td>
#       <td id="T_2643d_row7_col5" class="data row7 col5" >0.6163</td>
#       <td id="T_2643d_row7_col6" class="data row7 col6" >0.6168</td>
#     </tr>
#     <tr>
#       <th id="T_2643d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2643d_row8_col0" class="data row8 col0" >0.8113</td>
#       <td id="T_2643d_row8_col1" class="data row8 col1" >0.8746</td>
#       <td id="T_2643d_row8_col2" class="data row8 col2" >0.6111</td>
#       <td id="T_2643d_row8_col3" class="data row8 col3" >0.7857</td>
#       <td id="T_2643d_row8_col4" class="data row8 col4" >0.6875</td>
#       <td id="T_2643d_row8_col5" class="data row8 col5" >0.5554</td>
#       <td id="T_2643d_row8_col6" class="data row8 col6" >0.5644</td>
#     </tr>
#     <tr>
#       <th id="T_2643d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2643d_row9_col0" class="data row9 col0" >0.7736</td>
#       <td id="T_2643d_row9_col1" class="data row9 col1" >0.8286</td>
#       <td id="T_2643d_row9_col2" class="data row9 col2" >0.6667</td>
#       <td id="T_2643d_row9_col3" class="data row9 col3" >0.6667</td>
#       <td id="T_2643d_row9_col4" class="data row9 col4" >0.6667</td>
#       <td id="T_2643d_row9_col5" class="data row9 col5" >0.4952</td>
#       <td id="T_2643d_row9_col6" class="data row9 col6" >0.4952</td>
#     </tr>
#     <tr>
#       <th id="T_2643d_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T
_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5b4e1_row8_col0" class="data row8 col0" >0.8113</td>
#       <td id="T_5b4e1_row8_col1" class="data row8 col1" >0.8778</td>
#       <td id="T_5b4e1_row8_col2" class="data row8 col2" >0.6111</td>
#       <td id="T_5b4e1_row8_col3" class="data row8 col3" >0.7857</td>
#       <td id="T_5b4e1_row8_col4" class="data row8 col4" >0.6875</td>
#       <td id="T_5b4e1_row8_col5" class="data row8 col5" >0.5554</td>
#       <td id="T_5b4e1_row8_col6" class="data row8 col6" >0.5644</td>
#     </tr>
#     <tr>
#       <th id="T_5b4e1_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5b4e1_row9_col0" class="data row9 col0" >0.7736</td>
#       <td id="T_5b4e1_row9_col1" class="data row9 col1" >0.8302</td>
#       <td id="T_5b4e1_row9_col2" class="data row9 col2" >0.6667</td>
#       <td id="T_5b4e1_row9_col3" class="data row9 col3" >0.6667</td>
#       <td id="T_5b4e1_row9_col4" class="data row9 col4" >0.6667</td>
#       <td id="T_5b4e1_row9_col5" class="data row9 col5" >0.4952</td>
#       <td id="T_5b4e1_row9_col6" class="data row9 col6" >0.4952</td>
#     </tr>
#     <tr>
#       <th id="T_5b4e1_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_5b4e1_row10_col0" class="data row10 col0" >0.7841</td>
#       <td id="T_5b4e1_row10_col1" class="data row10 col1" >0.8476</td>
#       <td id="T_5b4e1_row10_col2" class="data row10 col2" >0.6000</td>
#       <td id="T_5b4e1_row10_col3" class="data row10 col3" >0.7341</td>
#       <td id="T_5b4e1_row10_col4" class="data row10 col4" >0.6568</td>
#       <td id="T_5b4e1_row10_col5" class="data row10 col5" >0.5026</td>
#       <td id="T_5b4e1_row10_col6" class="data row10 col6" >0.5104</td>
#     </tr>
#     <tr>
#       <th id="T_5b4e1_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_5b4e1_row11_col0" class="data row11 col0" >0.0411</td>
#       <td id="T_5b4e1_row11_col1" class="data row11 col1" >0.0414</td>
#       <td id="T_5b4e1_row11_col2" class="data row11 col2" >0.0941</td>
#       <td id="T_5b4e1_row11_col3" class="data row11 col3" >0.0701</td>
#       <td id="T_5b4e1_row11_col4
# <style type="text/css">
# #T_f010b_row10_col0, #T_f010b_row10_col1, #T_f010b_row10_col2, #T_f010b_row10_col3, #T_f010b_row10_col4, #T_f010b_row10_col5, #T_f010b_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_f010b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f010b_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_f010b_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_f010b_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_f010b_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_f010b_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_f010b_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_f010b_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f010b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f010b_row0_col0" class="data row0 col0" >0.7222</td>
#       <td id="T_f010b_row0_col1" class="data row0 col1" >0.8391</td>
#       <td id="T_f010b_row0_col2" class="data row0 col2" >0.5263</td>
#       <td id="T_f010b_row0_col3" class="data row0 col3" >0.6250</td>
#       <td id="T_f010b_row0_col4" class="data row0 col4" >0.5714</td>
#       <td id="T_f010b_row0_col5" class="data row0 col5" >0.3682</td>
#       <td id="T_f010b_row0_col6" class="data row0 col6" >0.3711</td>
#     </tr>
#     <tr>
#       <th id="T_f010b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f010b_row1_col0" class="data row1 col0" >0.6667</td>
#       <td id="T_f010b_row1_col1" class="data row1 col1" >0.7414</td>
#       <td id="T_f010b_row1_col2" class="data row1 col2" >0.5789</td>
#       <td id="T_f010b_row1_col3" class="data row1 col3" >0.5238</td>
#       <td id="T_f010b_row1_col4" class="data row1 col4" >0.5500</td>
#       <td id="T_f010b_row1_col5" class="data row1 col5" >0.2863</td>
#       <td id="T_f010b_row1_col6" class="data row1 col6" >0.2872</td>
#     </tr>
#     <tr>
#       <th id="T_f010b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f010b_row2_col0" class="data row2 col0" >0.8519</td>
#       <td id="T_f010b_row2_col1" class="data row2 col1" >0.9308</td>
#       <td id="T_f010b_row2_col2" class="data row2 col2" >0.8421</td>
#       <td id="T_f010b_row2_col3" class="data row2 col3" >0.7619</td>
#       <td id="T_f010b_row2_col4" class="data row2 col4" >0.8000</td>
#       <td id="T_f010b_row2_col5" class="data row2 col5" >0.6828</td>
#       <td id="T_f010b_row2_col6" class="data row2 col6" >0.6850</td>
#     </tr>
#     <tr>
#       <th id="T_f010b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f010b_row3_col0" class="data row3 col0" >0.6667</td>
#       <td id="T_f010b_row3_col1" class="data row3 col1" >0.7835</td>
#       <td id="T_f010b_row3_col2" class="data row3 col2" >0.3684</td>
#       <td id="T_f010b_row3_col3" class="data row3 col3" >0.5385</td>
#       <td id="T_f010b_row3_col4" class="data row3 col4" >0.4375</td>
#       <td id="T_f010b_row3_col5" class="data row3 col5" >0.2123</td>
#       <td id="T_f010b_row3_col6" class="data row3 col6" >0.2200</td>
#     </tr>
#     <tr>
#       <th id="T_f010b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f010b_row4_col0" class="data row4 col0" >0.7778</td>
#       <td id="T_f010b_row4_col1" class="data row4 col1" >0.8165</td>
#       <td id="T_f010b_row4_col2" class="data row4 col2" >0.5263</td>
#       <td id="T_f010b_row4_col3" class="data row4 col3" >0.7692</td>
#       <td id="T_f010b_row4_col4" class="data row4 col4" >0.6250</td>
#       <td id="T_f010b_row4_col5" class="data row4 col5" >0.4749</td>
#       <td id="T_f010b_row4_col6" class="data row4 col6" >0.4921</td>
#     </tr>
#     <tr>
#       <th id="T_f010b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f010b_row5_col0" class="data row5 col0" >0.8519</td>
#       <td id="T_f010b_row5_col1" class="data row5 col1" >0.8586</td>
#       <td id="T_f010b_row5_col2" class="data row5 col2" >0.7368</td>
#       <td id="T_f010b_row5_col3" class="data row5 col3" >0.8235</td>
#       <td id="T_f010b_row5_col4" class="data row5 col4" >0.7778</td>
#       <td id="T_f010b_row5_col5" class="data row5 col5" >0.6672</td>
#       <td id="T_f010b_row5_col6" class="data row5 col6" >0.6695</td>
#     </tr>
#     <tr>
#       <th id="T_f010b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f010b_row6_col0" class="data row6 col0" >0.7778</td>
#       <td id="T_f010b_row6_col1" class="data row6 col1" >0.8662</td>
#       <td id="T_f010b_row6_col2" class="data row6 col2" >0.5263</td>
#       <td id="T_f010b_row6_col3" class="data row6 col3" >0.7692</td>
#       <td id="T_f010b_row6_col4" class="data row6 col4" >0.6250</td>
#       <td id="T_f010b_row6_col5" class="data row6 col5" >0.4749</td>
#       <td id="T_f010b_row6_col6" class="data row6 col6" >0.4921</td>
#     </tr>
#     <tr>
#       <th id="T_f010b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f010b_row7_col0" class="data row7 col0" >0.8491</td>
#       <td id="T_f010b_row7_col1" class="data row7 col1" >0.8857</td>
#       <td id="T_f010b_row7_col2" class="data row7 col2" >0.8333</td>
#       <td id="T_f010b_row7_col3" class="data row7 col3" >0.7500</td>
#       <td id="T_f010b_row7_col4" class="data row7 col4" >0.7895</td>
#       <td id="T_f010b_row7_col5" class="data row7 col5" >0.6723</td>
#       <td id="T_f010b_row7_col6" class="data row7 col6" >0.6746</td>
#     </tr>
#     <tr>
#       <th id="T_f010b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f010b_row8_col0" class="data row8 col0" >0.7736</td>
#       <td id="T_f010b_row8_col1" class="data row8 col1" >0.8524</td>
#       <td id="T_f010b_row8_col2" class="data row8 col2" >0.6667</td>
#       <td id="T_f010b_row8_col3" class="data row8 col3" >0.6667</td>
#       <td id="T_f010b_row8_col4" class="data row8 col4" >0.6667</td>
#       <td id="T_f010b_row8_col5" class="data row8 col5" >0.4952</td>
#       <td id="T_f010b_row8_col6" class="data row8 col6" >0.4952</td>
#     </tr>
#     <tr>
#       <th id="T_f010b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f010b_row9_col0" class="data row9 col0" >0.7547</td>
#       <td id="T_f010b_row9_col1" class="data row9 col1" >0.7746</td>
#       <td id="T_f010b_row9_col2" class="data row9 col2" >0.8333</td>
#       <td id="T_f010b_row9_col3" class="data row9 col3" >0.6000</td>
#       <td id="T_f010b_row9_col4" class="data row9 col4" >0.6977</td>
#       <td id="T_f010b_row9_col5" class="data row9 col5" >0.5004</td>
#       <td id="T_f010b_row9_col6" class="data row9 col6" >0.5195</td>
#     </tr>
#     <tr>
#       <th id="T_f010b_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_f010b_row10_col0" class="data row10 col0" >0.7692</td>
#       <td id="T_f010b_row10_col1" class="data row10 col1" >0.8349</td>
#       <td id="T_f010b_row10_col2" class="data row10 col2" >0.6439</td>
#       <td id="T_f010b_row10_col3" class="data row10 col3" >0.6828</td>
#       <td id="T_f010b_row10_col4" class="data row10 col4" >0.6541</td>
#       <td id="T_f010b_row10_col5" class="data row10 col5" >0.4835</td>
#       <td id="T_f010b_row10_col6" class="data row10 col6" >0.4907</td>
#     </tr>
#     <tr>
#       <th id="T_f010b_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_f010b_row11_col0" class="data row11 col0" >0.0661</td>
#       <td id="T_f010b_row11_col1" class="data row11 col1" >0.0539</td>
#       <td id="T_f010b_row11_col2" class="data row11 col2" >0.1555</td>
#       <td id="T_f010b_row11_col3" class="data row11 col3" >0.1010</td>
#       <td id="T_f010b_row11_col4

# %% [markdown]
# ## Interpreting Models

# %%
interpret_model(catboost)

# %%
interpret_model(rf)

# %% [markdown]
# <span style="color:Blue"> **Observation:**
# * As expected, glucose is used as the most important feature.
# * SkinTickness and BloodPressure have the low importance.

# %% [markdown]
# Let's compare the feature importance of the above two models. A comparison was made with SHAP values, and the feature importance of each model is slightly different.
# The diversity of each model seems to be stable and improve performance while compensating for each other's weaknesses.
#
# If you are more interested in feature importance, please refer to the notebook below.
#
# [Notebook](https://www.kaggle.com/ohseokkim/interpreting-models-by-feature-importnace)

# %% [markdown]
# # Tuning Hyperparameters
#
# > This function tunes the hyperparameters of a given estimator. The output of this function is a score grid with CV scores by fold of the best selected model based on optimize parameter.

# %%
tuned_catboost = tune_model(catboost, optimize = 'AUC')
tuned_rf = tune_model(rf, optimize = 'AUC')
tuned_lr = tune_model(lr, optimize = 'AUC')
tuned_lda = tune_model(lda, optimize = 'AUC')
tuned_gbc = tune_model(gbc, optimize = 'AUC')
# Out:
# <style type="text/css">
# #T_c41d4_row10_col0, #T_c41d4_row10_col1, #T_c41d4_row10_col2, #T_c41d4_row10_col3, #T_c41d4_row10_col4, #T_c41d4_row10_col5, #T_c41d4_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_c41d4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c41d4_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_c41d4_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_c41d4_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_c41d4_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_c41d4_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_c41d4_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_c41d4_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c41d4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c41d4_row0_col0" class="data row0 col0" >0.7593</td>
#       <td id="T_c41d4_row0_col1" class="data row0 col1" >0.8707</td>
#       <td id="T_c41d4_row0_col2" class="data row0 col2" >0.5263</td>
#       <td id="T_c41d4_row0_col3" class="data row0 col3" >0.7143</td>
#       <td id="T_c41d4_row0_col4" class="data row0 col4" >0.6061</td>
#       <td id="T_c41d4_row0_col5" class="data row0 col5" >0.4384</td>
#       <td id="T_c41d4_row0_col6" class="data row0 col6" >0.4490</td>
#     </tr>
#     <tr>
#       <th id="T_c41d4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c41d4_row1_col0" class="data row1 col0" >0.7407</td>
#       <td id="T_c41d4_row1_col1" class="data row1 col1" >0.7917</td>
#       <td id="T_c41d4_row1_col2" class="data row1 col2" >0.5789</td>
#       <td id="T_c41d4_row1_col3" class="data row1 col3" >0.6471</td>
#       <td id="T_c41d4_row1_col4" class="data row1 col4" >0.6111</td>
#       <td id="T_c41d4_row1_col5" class="data row1 col5" >0.4176</td>
#       <td id="T_c41d4_row1_col6" class="data row1 col6" >0.4190</td>
#     </tr>
#     <tr>
#       <th id="T_c41d4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c41d4_row2_col0" class="data row2 col0" >0.8333</td>
#       <td id="T_c41d4_row2_col1" class="data row2 col1" >0.9338</td>
#       <td id="T_c41d4_row2_col2" class="data row2 col2" >0.7368</td>
#       <td id="T_c41d4_row2_col3" class="data row2 col3" >0.7778</td>
#       <td id="T_c41d4_row2_col4" class="data row2 col4" >0.7568</td>
#       <td id="T_c41d4_row2_col5" class="data row2 col5" >0.6301</td>
#       <td id="T_c41d4_row2_col6" class="data row2 col6" >0.6307</td>
#     </tr>
#     <tr>
#       <th id="T_c41d4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c41d4_row3_col0" class="data row3 col0" >0.6481</td>
#       <td id="T_c41d4_row3_col1" class="data row3 col1" >0.7872</td>
#       <td id="T_c41d4_row3_col2" class="data row3 col2" >0.3158</td>
#       <td id="T_c41d4_row3_col3" class="data row3 col3" >0.5000</td>
#       <td id="T_c41d4_row3_col4" class="data row3 col4" >0.3871</td>
#       <td id="T_c41d4_row3_col5" class="data row3 col5" >0.1576</td>
#       <td id="T_c41d4_row3_col6" class="data row3 col6" >0.1658</td>
#     </tr>
#     <tr>
#       <th id="T_c41d4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c41d4_row4_col0" class="data row4 col0" >0.7593</td>
#       <td id="T_c41d4_row4_col1" class="data row4 col1" >0.8353</td>
#       <td id="T_c41d4_row4_col2" class="data row4 col2" >0.5263</td>
#       <td id="T_c41d4_row4_col3" class="data row4 col3" >0.7143</td>
#       <td id="T_c41d4_row4_col4" class="data row4 col4" >0.6061</td>
#       <td id="T_c41d4_row4_col5" class="data row4 col5" >0.4384</td>
#       <td id="T_c41d4_row4_col6" class="data row4 col6" >0.4490</td>
#     </tr>
#     <tr>
#       <th id="T_c41d4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c41d4_row5_col0" class="data row5 col0" >0.8148</td>
#       <td id="T_c41d4_row5_col1" class="data row5 col1" >0.8632</td>
#       <td id="T_c41d4_row5_col2" class="data row5 col2" >0.5789</td>
#       <td id="T_c41d4_row5_col3" class="data row5 col3" >0.8462</td>
#       <td id="T_c41d4_row5_col4" class="data row5 col4" >0.6875</td>
#       <td id="T_c41d4_row5_col5" class="data row5 col5" >0.5624</td>
#       <td id="T_c41d4_row5_col6" class="data row5 col6" >0.5828</td>
#     </tr>
#     <tr>
#       <th id="T_c41d4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c41d4_row6_col0" class="data row6 col0" >0.7778</td>
#       <td id="T_c41d4_row6_col1" class="data row6 col1" >0.8662</td>
#       <td id="T_c41d4_row6_col2" class="data row6 col2" >0.5263</td>
#       <td id="T_c41d4_row6_col3" class="data row6 col3" >0.7692</td>
#       <td id="T_c41d4_row6_col4" class="data row6 col4" >0.6250</td>
#       <td id="T_c41d4_row6_col5" class="data row6 col5" >0.4749</td>
#       <td id="T_c41d4_row6_col6" class="data row6 col6" >0.4921</td>
#     </tr>
#     <tr>
#       <th id="T_c41d4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c41d4_row7_col0" class="data row7 col0" >0.8491</td>
#       <td id="T_c41d4_row7_col1" class="data row7 col1" >0.8873</td>
#       <td id="T_c41d4_row7_col2" class="data row7 col2" >0.8333</td>
#       <td id="T_c41d4_row7_col3" class="data row7 col3" >0.7500</td>
#       <td id="T_c41d4_row7_col4" class="data row7 col4" >0.7895</td>
#       <td id="T_c41d4_row7_col5" class="data row7 col5" >0.6723</td>
#       <td id="T_c41d4_row7_col6" class="data row7 col6" >0.6746</td>
#     </tr>
#     <tr>
#       <th id="T_c41d4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c41d4_row8_col0" class="data row8 col0" >0.8113</td>
#       <td id="T_c41d4_row8_col1" class="data row8 col1" >0.9000</td>
#       <td id="T_c41d4_row8_col2" class="data row8 col2" >0.7222</td>
#       <td id="T_c41d4_row8_col3" class="data row8 col3" >0.7222</td>
#       <td id="T_c41d4_row8_col4" class="data row8 col4" >0.7222</td>
#       <td id="T_c41d4_row8_col5" class="data row8 col5" >0.5794</td>
#       <td id="T_c41d4_row8_col6" class="data row8 col6" >0.5794</td>
#     </tr>
#     <tr>
#       <th id="T_c41d4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c41d4_row9_col0" class="data row9 col0" >0.7736</td>
#       <td id="T_c41d4_row9_col1" class="data row9 col1" >0.8222</td>
#       <td id="T_c41d4_row9_col2" class="data row9 col2" >0.7778</td>
#       <td id="T_c41d4_row9_col3" class="data row9 col3" >0.6364</td>
#       <td id="T_c41d4_row9_col4" class="data row9 col4" >0.7000</td>
#       <td id="T_c41d4_row9_col5" class="data row9 col5" >0.5211</td>
#       <td id="T_c41d4_row9_col6" class="data row9 col6" >0.5279</td>
#     </tr>
#     <tr>
#       <th id="T_c41d4_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_c41d4_row10_col0" class="data row10 col0" >0.7767</td>
#       <td id="T_c41d4_row10_col1" class="data row10 col1" >0.8558</td>
#       <td id="T_c41d4_row10_col2" class="data row10 col2" >0.6123</td>
#       <td id="T_c41d4_row10_col3" class="data row10 col3" >0.7077</td>
#       <td id="T_c41d4_row10_col4" class="data row10 col4" >0.6491</td>
#       <td id="T_c41d4_row10_col5" class="data row10 col5" >0.4892</td>
#       <td id="T_c41d4_row10_col6" class="data row10 col6" >0.4970</td>
#     </tr>
#     <tr>
#       <th id="T_c41d4_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_c41d4_row11_col0" class="data row11 col0" >0.0543</td>
#       <td id="T_c41d4_row11_col1" class="data row11 col1" >0.0445</td>
#       <td id="T_c41d4_row11_col2" class="data row11 col2" >0.1470</td>
#       <td id="T_c41d4_row11_col3" class="data row11 col3" >0.0905</td>
#       <td id="T_c41d4_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# <style type="text/css">
# #T_fdff5_row10_col0, #T_fdff5_row10_col1, #T_fdff5_row10_col2, #T_fdff5_row10_col3, #T_fdff5_row10_col4, #T_fdff5_row10_col5, #T_fdff5_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_fdff5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fdff5_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_fdff5_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_fdff5_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_fdff5_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_fdff5_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_fdff5_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_fdff5_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fdff5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fdff5_row0_col0" class="data row0 col0" >0.7963</td>
#       <td id="T_fdff5_row0_col1" class="data row0 col1" >0.8947</td>
#       <td id="T_fdff5_row0_col2" class="data row0 col2" >0.6842</td>
#       <td id="T_fdff5_row0_col3" class="data row0 col3" >0.7222</td>
#       <td id="T_fdff5_row0_col4" class="data row0 col4" >0.7027</td>
#       <td id="T_fdff5_row0_col5" class="data row0 col5" >0.5479</td>
#       <td id="T_fdff5_row0_col6" class="data row0 col6" >0.5484</td>
#     </tr>
#     <tr>
#       <th id="T_fdff5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fdff5_row1_col0" class="data row1 col0" >0.7593</td>
#       <td id="T_fdff5_row1_col1" class="data row1 col1" >0.7639</td>
#       <td id="T_fdff5_row1_col2" class="data row1 col2" >0.6842</td>
#       <td id="T_fdff5_row1_col3" class="data row1 col3" >0.6500</td>
#       <td id="T_fdff5_row1_col4" class="data row1 col4" >0.6667</td>
#       <td id="T_fdff5_row1_col5" class="data row1 col5" >0.4785</td>
#       <td id="T_fdff5_row1_col6" class="data row1 col6" >0.4788</td>
#     </tr>
#     <tr>
#       <th id="T_fdff5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fdff5_row2_col0" class="data row2 col0" >0.8519</td>
#       <td id="T_fdff5_row2_col1" class="data row2 col1" >0.9323</td>
#       <td id="T_fdff5_row2_col2" class="data row2 col2" >0.8421</td>
#       <td id="T_fdff5_row2_col3" class="data row2 col3" >0.7619</td>
#       <td id="T_fdff5_row2_col4" class="data row2 col4" >0.8000</td>
#       <td id="T_fdff5_row2_col5" class="data row2 col5" >0.6828</td>
#       <td id="T_fdff5_row2_col6" class="data row2 col6" >0.6850</td>
#     </tr>
#     <tr>
#       <th id="T_fdff5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fdff5_row3_col0" class="data row3 col0" >0.6852</td>
#       <td id="T_fdff5_row3_col1" class="data row3 col1" >0.7699</td>
#       <td id="T_fdff5_row3_col2" class="data row3 col2" >0.4737</td>
#       <td id="T_fdff5_row3_col3" class="data row3 col3" >0.5625</td>
#       <td id="T_fdff5_row3_col4" class="data row3 col4" >0.5143</td>
#       <td id="T_fdff5_row3_col5" class="data row3 col5" >0.2839</td>
#       <td id="T_fdff5_row3_col6" class="data row3 col6" >0.2862</td>
#     </tr>
#     <tr>
#       <th id="T_fdff5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fdff5_row4_col0" class="data row4 col0" >0.7407</td>
#       <td id="T_fdff5_row4_col1" class="data row4 col1" >0.8256</td>
#       <td id="T_fdff5_row4_col2" class="data row4 col2" >0.5263</td>
#       <td id="T_fdff5_row4_col3" class="data row4 col3" >0.6667</td>
#       <td id="T_fdff5_row4_col4" class="data row4 col4" >0.5882</td>
#       <td id="T_fdff5_row4_col5" class="data row4 col5" >0.4028</td>
#       <td id="T_fdff5_row4_col6" class="data row4 col6" >0.4088</td>
#     </tr>
#     <tr>
#       <th id="T_fdff5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fdff5_row5_col0" class="data row5 col0" >0.7778</td>
#       <td id="T_fdff5_row5_col1" class="data row5 col1" >0.8376</td>
#       <td id="T_fdff5_row5_col2" class="data row5 col2" >0.5263</td>
#       <td id="T_fdff5_row5_col3" class="data row5 col3" >0.7692</td>
#       <td id="T_fdff5_row5_col4" class="data row5 col4" >0.6250</td>
#       <td id="T_fdff5_row5_col5" class="data row5 col5" >0.4749</td>
#       <td id="T_fdff5_row5_col6" class="data row5 col6" >0.4921</td>
#     </tr>
#     <tr>
#       <th id="T_fdff5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fdff5_row6_col0" class="data row6 col0" >0.7963</td>
#       <td id="T_fdff5_row6_col1" class="data row6 col1" >0.8782</td>
#       <td id="T_fdff5_row6_col2" class="data row6 col2" >0.5789</td>
#       <td id="T_fdff5_row6_col3" class="data row6 col3" >0.7857</td>
#       <td id="T_fdff5_row6_col4" class="data row6 col4" >0.6667</td>
#       <td id="T_fdff5_row6_col5" class="data row6 col5" >0.5248</td>
#       <td id="T_fdff5_row6_col6" class="data row6 col6" >0.5375</td>
#     </tr>
#     <tr>
#       <th id="T_fdff5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_fdff5_row7_col0" class="data row7 col0" >0.8491</td>
#       <td id="T_fdff5_row7_col1" class="data row7 col1" >0.8778</td>
#       <td id="T_fdff5_row7_col2" class="data row7 col2" >0.8333</td>
#       <td id="T_fdff5_row7_col3" class="data row7 col3" >0.7500</td>
#       <td id="T_fdff5_row7_col4" class="data row7 col4" >0.7895</td>
#       <td id="T_fdff5_row7_col5" class="data row7 col5" >0.6723</td>
#       <td id="T_fdff5_row7_col6" class="data row7 col6" >0.6746</td>
#     </tr>
#     <tr>
#       <th id="T_fdff5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_fdff5_row8_col0" class="data row8 col0" >0.7736</td>
#       <td id="T_fdff5_row8_col1" class="data row8 col1" >0.8746</td>
#       <td id="T_fdff5_row8_col2" class="data row8 col2" >0.6667</td>
#       <td id="T_fdff5_row8_col3" class="data row8 col3" >0.6667</td>
#       <td id="T_fdff5_row8_col4" class="data row8 col4" >0.6667</td>
#       <td id="T_fdff5_row8_col5" class="data row8 col5" >0.4952</td>
#       <td id="T_fdff5_row8_col6" class="data row8 col6" >0.4952</td>
#     </tr>
#     <tr>
#       <th id="T_fdff5_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_fdff5_row9_col0" class="data row9 col0" >0.8113</td>
#       <td id="T_fdff5_row9_col1" class="data row9 col1" >0.8286</td>
#       <td id="T_fdff5_row9_col2" class="data row9 col2" >0.8333</td>
#       <td id="T_fdff5_row9_col3" class="data row9 col3" >0.6818</td>
#       <td id="T_fdff5_row9_col4" class="data row9 col4" >0.7500</td>
#       <td id="T_fdff5_row9_col5" class="data row9 col5" >0.6009</td>
#       <td id="T_fdff5_row9_col6" class="data row9 col6" >0.6087</td>
#     </tr>
#     <tr>
#       <th id="T_fdff5_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_fdff5_row10_col0" class="data row10 col0" >0.7841</td>
#       <td id="T_fdff5_row10_col1" class="data row10 col1" >0.8483</td>
#       <td id="T_fdff5_row10_col2" class="data row10 col2" >0.6649</td>
#       <td id="T_fdff5_row10_col3" class="data row10 col3" >0.7017</td>
#       <td id="T_fdff5_row10_col4" class="data row10 col4" >0.6770</td>
#       <td id="T_fdff5_row10_col5" class="data row10 col5" >0.5164</td>
#       <td id="T_fdff5_row10_col6" class="data row10 col6" >0.5215</td>
#     </tr>
#     <tr>
#       <th id="T_fdff5_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_fdff5_row11_col0" class="data row11 col0" >0.0472</td>
#       <td id="T_fdff5_row11_col1" class="data row11 col1" >0.0509</td>
#       <td id="T_fdff5_row11_col2" class="data row11 col2" >0.1309</td>
#       <td id="T_fdff5_row11_col3" class="data row11 col3" >0.0655</td>
#       <td id="T_fdff5_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# <style type="text/css">
# #T_7b332_row10_col0, #T_7b332_row10_col1, #T_7b332_row10_col2, #T_7b332_row10_col3, #T_7b332_row10_col4, #T_7b332_row10_col5, #T_7b332_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_7b332">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7b332_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_7b332_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_7b332_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_7b332_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_7b332_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_7b332_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_7b332_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7b332_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7b332_row0_col0" class="data row0 col0" >0.7778</td>
#       <td id="T_7b332_row0_col1" class="data row0 col1" >0.8767</td>
#       <td id="T_7b332_row0_col2" class="data row0 col2" >0.6842</td>
#       <td id="T_7b332_row0_col3" class="data row0 col3" >0.6842</td>
#       <td id="T_7b332_row0_col4" class="data row0 col4" >0.6842</td>
#       <td id="T_7b332_row0_col5" class="data row0 col5" >0.5128</td>
#       <td id="T_7b332_row0_col6" class="data row0 col6" >0.5128</td>
#     </tr>
#     <tr>
#       <th id="T_7b332_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7b332_row1_col0" class="data row1 col0" >0.6852</td>
#       <td id="T_7b332_row1_col1" class="data row1 col1" >0.7940</td>
#       <td id="T_7b332_row1_col2" class="data row1 col2" >0.6316</td>
#       <td id="T_7b332_row1_col3" class="data row1 col3" >0.5455</td>
#       <td id="T_7b332_row1_col4" class="data row1 col4" >0.5854</td>
#       <td id="T_7b332_row1_col5" class="data row1 col5" >0.3338</td>
#       <td id="T_7b332_row1_col6" class="data row1 col6" >0.3361</td>
#     </tr>
#     <tr>
#       <th id="T_7b332_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_
col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_4391d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4391d_row9_col0" class="data row9 col0" >0.6604</td>
#       <td id="T_4391d_row9_col1" class="data row9 col1" >0.8175</td>
#       <td id="T_4391d_row9_col2" class="data row9 col2" >0.0000</td>
#       <td id="T_4391d_row9_col3" class="data row9 col3" >0.0000</td>
#       <td id="T_4391d_row9_col4" class="data row9 col4" >0.0000</td>
#       <td id="T_4391d_row9_col5" class="data row9 col5" >0.0000</td>
#       <td id="T_4391d_row9_col6" class="data row9 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_4391d_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_4391d_row10_col0" class="data row10 col0" >0.6518</td>
#       <td id="T_4391d_row10_col1" class="data row10 col1" >0.8424</td>
#       <td id="T_4391d_row10_col2" class="data row10 col2" >0.0000</td>
#       <td id="T_4391d_row10_col3" class="data row10 col3" >0.0000</td>
#       <td id="T_4391d_row10_col4" class="data row10 col4" >0.0000</td>
#       <td id="T_4391d_row10_col5" class="data row10 col5" >0.0000</td>
#       <td id="T_4391d_row10_col6" class="data row10 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_4391d_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_4391d_row11_col0" class="data row11 col0" >0.0056</td>
#       <td id="T_4391d_row11_col1" class="data row11 col1" >0.0471</td>
#       <td id="T_4391d_row11_col2" class="data row11 col2" >0.0000</td>
#       <td id="T_4391d_row11_col3" class="data row11 col3" >0.0000</td>
#       <td id="T_4391d_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits

# %% [markdown]
# Top 1, Top 2, Top 3 ,Top 4, and Top 5 models were tuned with different feature importance and decision boundary. Also, there is a big difference in feature importance from the catboost classifier.

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------------------------
# # Stacking
#
# ![](https://miro.medium.com/max/1000/1*CoauXirckomVXxw2Id2w_Q.jpeg)
#
# Picture Credit: https://miro.medium.com

# %%
stack_model = stack_models(estimator_list = top5, meta_model = top5[0],optimize = 'AUC')
# Out:
# <style type="text/css">
# #T_5d774_row10_col0, #T_5d774_row10_col1, #T_5d774_row10_col2, #T_5d774_row10_col3, #T_5d774_row10_col4, #T_5d774_row10_col5, #T_5d774_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_5d774">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5d774_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_5d774_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_5d774_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_5d774_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_5d774_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_5d774_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_5d774_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5d774_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5d774_row0_col0" class="data row0 col0" >0.7593</td>
#       <td id="T_5d774_row0_col1" class="data row0 col1" >0.8421</td>
#       <td id="T_5d774_row0_col2" class="data row0 col2" >0.5789</td>
#       <td id="T_5d774_row0_col3" class="data row0 col3" >0.6875</td>
#       <td id="T_5d774_row0_col4" class="data row0 col4" >0.6286</td>
#       <td id="T_5d774_row0_col5" class="data row0 col5" >0.4524</td>
#       <td id="T_5d774_row0_col6" class="data row0 col6" >0.4561</td>
#     </tr>
#     <tr>
#       <th id="T_5d774_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5d774_row1_col0" class="data row1 col0" >0.7778</td>
#       <td id="T_5d774_row1_col1" class="data row1 col1" >0.7789</td>
#       <td id="T_5d774_row1_col2" class="data row1 col2" >0.6316</td>
#       <td id="T_5d774_row1_col3" class="data row1 col3" >0.7059</td>
#       <td id="T_5d774_row1_col4" class="data row1 col4" >0.6667</td>
#       <td id="T_5d774_row1_col5" class="data row1 col5" >0.5008</td>
#       <td id="T_5d774_row1_col6" class="data row1 col6" >0.5025</td>
#     </tr>
#     <tr>
#       <th id="T_5d774_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5d774_row2_col0" class="data row2 col0" >0.8519</td>
#       <td id="T_5d774_row2_col1" class="data row2 col1" >0.9293</td>
#       <td id="T_5d774_row2_col2" class="data row2 col2" >0.8421</td>
#       <td id="T_5d774_row2_col3" class="data row2 col3" >0.7619</td>
#       <td id="T_5d774_row2_col4" class="data row2 col4" >0.8000</td>
#       <td id="T_5d774_row2_col5" class="data row2 col5" >0.6828</td>
#       <td id="T_5d774_row2_col6" class="data row2 col6" >0.6850</td>
#     </tr>
#     <tr>
#       <th id="T_5d774_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5d774_row3_col0" class="data row3 col0" >0.6852</td>
#       <td id="T_5d774_row3_col1" class="data row3 col1" >0.7835</td>
#       <td id="T_5d774_row3_col2" class="data row3 col2" >0.4211</td>
#       <td id="T_5d774_row3_col3" class="data row3 col3" >0.5714</td>
#       <td id="T_5d774_row3_col4" class="data row3 col4" >0.4848</td>
#       <td id="T_5d774_row3_col5" class="data row3 col5" >0.2656</td>
#       <td id="T_5d774_row3_col6" class="data row3 col6" >0.2720</td>
#     </tr>
#     <tr>
#       <th id="T_5d774_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5d774_row4_col0" class="data row4 col0" >0.7778</td>
#       <td id="T_5d774_row4_col1" class="data row4 col1" >0.8211</td>
#       <td id="T_5d774_row4_col2" class="data row4 col2" >0.5789</td>
#       <td id="T_5d774_row4_col3" class="data row4 col3" >0.7333</td>
#       <td id="T_5d774_row4_col4" class="data row4 col4" >0.6471</td>
#       <td id="T_5d774_row4_col5" class="data row4 col5" >0.4882</td>
#       <td id="T_5d774_row4_col6" class="data row4 col6" >0.4954</td>
#     </tr>
#     <tr>
#       <th id="T_5d774_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5d774_row5_col0" class="data row5 col0" >0.7963</td>
#       <td id="T_5d774_row5_col1" class="data row5 col1" >0.8466</td>
#       <td id="T_5d774_row5_col2" class="data row5 col2" >0.5789</td>
#       <td id="T_5d774_row5_col3" class="data row5 col3" >0.7857</td>
#       <td id="T_5d774_row5_col4" class="data row5 col4" >0.6667</td>
#       <td id="T_5d774_row5_col5" class="data row5 col5" >0.5248</td>
#       <td id="T_5d774_row5_col6" class="data row5 col6" >0.5375</td>
#     </tr>
#     <tr>
#       <th id="T_5d774_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5d774_row6_col0" class="data row6 col0" >0.8148</td>
#       <td id="T_5d774_row6_col1" class="data row6 col1" >0.8752</td>
#       <td id="T_5d774_row6_col2" class="data row6 col2" >0.5789</td>
#       <td id="T_5d774_row6_col3" class="data row6 col3" >0.8462</td>
#       <td id="T_5d774_row6_col4" class="data row6 col4" >0.6875</td>
#       <td id="T_5d774_row6_col5" class="data row6 col5" >0.5624</td>
#       <td id="T_5d774_row6_col6" class="data row6 col6" >0.5828</td>
#     </tr>
#     <tr>
#       <th id="T_5d774_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5d774_row7_col0" class="data row7 col0" >0.8302</td>
#       <td id="T_5d774_row7_col1" class="data row7 col1" >0.8714</td>
#       <td id="T_5d774_row7_col2" class="data row7 col2" >0.7778</td>
#       <td id="T_5d774_row7_col3" class="data row7 col3" >0.7368</td>
#       <td id="T_5d774_row7_col4" class="data row7 col4" >0.7568</td>
#       <td id="T_5d774_row7_col5" class="data row7 col5" >0.6265</td>
#       <td id="T_5d774_row7_col6" class="data row7 col6" >0.6270</td>
#     </tr>
#     <tr>
#       <th id="T_5d774_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5d774_row8_col0" class="data row8 col0" >0.8302</td>
#       <td id="T_5d774_row8_col1" class="data row8 col1" >0.8825</td>
#       <td id="T_5d774_row8_col2" class="data row8 col2" >0.7222</td>
#       <td id="T_5d774_row8_col3" class="data row8 col3" >0.7647</td>
#       <td id="T_5d774_row8_col4" class="data row8 col4" >0.7429</td>
#       <td id="T_5d774_row8_col5" class="data row8 col5" >0.6163</td>
#       <td id="T_5d774_row8_col6" class="data row8 col6" >0.6168</td>
#     </tr>
#     <tr>
#       <th id="T_5d774_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5d774_row9_col0" class="data row9 col0" >0.8302</td>
#       <td id="T_5d774_row9_col1" class="data row9 col1" >0.8413</td>
#       <td id="T_5d774_row9_col2" class="data row9 col2" >0.8333</td>
#       <td id="T_5d774_row9_col3" class="data row9 col3" >0.7143</td>
#       <td id="T_5d774_row9_col4" class="data row9 col4" >0.7692</td>
#       <td id="T_5d774_row9_col5" class="data row9 col5" >0.6362</td>
#       <td id="T_5d774_row9_col6" class="data row9 col6" >0.6409</td>
#     </tr>
#     <tr>
#       <th id="T_5d774_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_5d774_row10_col0" class="data row10 col0" >0.7954</td>
#       <td id="T_5d774_row10_col1" class="data row10 col1" >0.8472</td>
#       <td id="T_5d774_row10_col2" class="data row10 col2" >0.6544</td>
#       <td id="T_5d774_row10_col3" class="data row10 col3" >0.7308</td>
#       <td id="T_5d774_row10_col4" class="data row10 col4" >0.6850</td>
#       <td id="T_5d774_row10_col5" class="data row10 col5" >0.5356</td>
#       <td id="T_5d774_row10_col6" class="data row10 col6" >0.5416</td>
#     </tr>
#     <tr>
#       <th id="T_5d774_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_5d774_row11_col0" class="data row11 col0" >0.0461</td>
#       <td id="T_5d774_row11_col1" class="data row11 col1" >0.0434</td>
#       <td id="T_5d774_row11_col2" class="data row11 col2" >0.1284</td>
#       <td id="T_5d774_row11_col3" class="data row11 col3" >0.0683</td>
#       <td id="T_5d774_row11_col4

# %%
plt.figure(figsize=(8, 8))
plot_model(stack_model, plot='boundary')

# %% [markdown]
# In the case of a stacking model, in some cases overfitting and in some cases underfitting.
#
# If you are interested in under/overfitting, please refer to the notebook below.
#
# [Notebook](https://www.kaggle.com/ohseokkim/overfitting-and-underfitting-eda)
#
# Let's compare the other model's boundary.

# %%
plt.figure(figsize=(8, 8))
plot_model(stack_model, plot = 'auc')

# %%
#prediction
pred = stack_model.predict(X_test)
pred_proba = stack_model.predict_proba(X_test)[:,1]
#Accuracy
confusion_stack = get_clf_eval(y_test,pred,pred_proba)
# Out:
# accuracy: 0.8281, precision: 0.8000, recall: 0.6957,    F1: 0.7442, AUC:0.9077

# %%
plt.figure(figsize=(8, 6))
ax = sns.heatmap(confusion_stack, cmap = 'YlGnBu',annot = True, fmt='d')
ax.set_title('Confusion Matrix (Stacking)')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix (Stacking)')

# %% [markdown]
# Precision and recall have a trade-off relationship. The picture above seems to be well balanced because it has been studied well.

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------
# # Soft Voting
#
# ![](https://miro.medium.com/max/806/1*bliKQZGPccS7ho9Zo6uC7A.jpeg)
#
# Picture Credit: https://miro.medium.com
#
# > This function trains a Soft Voting classifier for select models passed in the estimator_list param. The output of this function is a score grid with CV scores by fold.
#
# Ref: https://pycaret.readthedocs.io/en/latest/api/classification.html

# %%
blend_soft = blend_models(estimator_list = top5, optimize = 'AUC',method = 'soft')
# Out:
# <style type="text/css">
# #T_9aba1_row10_col0, #T_9aba1_row10_col1, #T_9aba1_row10_col2, #T_9aba1_row10_col3, #T_9aba1_row10_col4, #T_9aba1_row10_col5, #T_9aba1_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_9aba1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9aba1_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_9aba1_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_9aba1_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_9aba1_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_9aba1_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_9aba1_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_9aba1_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9aba1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9aba1_row0_col0" class="data row0 col0" >0.7778</td>
#       <td id="T_9aba1_row0_col1" class="data row0 col1" >0.8707</td>
#       <td id="T_9aba1_row0_col2" class="data row0 col2" >0.6316</td>
#       <td id="T_9aba1_row0_col3" class="data row0 col3" >0.7059</td>
#       <td id="T_9aba1_row0_col4" class="data row0 col4" >0.6667</td>
#       <td id="T_9aba1_row0_col5" class="data row0 col5" >0.5008</td>
#       <td id="T_9aba1_row0_col6" class="data row0 col6" >0.5025</td>
#     </tr>
#     <tr>
#       <th id="T_9aba1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9aba1_row1_col0" class="data row1 col0" >0.7593</td>
#       <td id="T_9aba1_row1_col1" class="data row1 col1" >0.7714</td>
#       <td id="T_9aba1_row1_col2" class="data row1 col2" >0.5789</td>
#       <td id="T_9aba1_row1_col3" class="data row1 col3" >0.6875</td>
#       <td id="T_9aba1_row1_col4" class="data row1 col4" >0.6286</td>
#       <td id="T_9aba1_row1_col5" class="data row1 col5" >0.4524</td>
#       <td id="T_9aba1_row1_col6" class="data row1 col6" >0.4561</td>
#     </tr>
#     <tr>
#       <th id="T_9aba1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9aba1_row2_col0" class="data row2 col0" >0.8333</td>
#       <td id="T_9aba1_row2_col1" class="data row2 col1" >0.9368</td>
#       <td id="T_9aba1_row2_col2" class="data row2 col2" >0.7895</td>
#       <td id="T_9aba1_row2_col3" class="data row2 col3" >0.7500</td>
#       <td id="T_9aba1_row2_col4" class="data row2 col4" >0.7692</td>
#       <td id="T_9aba1_row2_col5" class="data row2 col5" >0.6389</td>
#       <td id="T_9aba1_row2_col6" class="data row2 col6" >0.6394</td>
#     </tr>
#     <tr>
#       <th id="T_9aba1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_
level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9aba1_row9_col0" class="data row9 col0" >0.8302</td>
#       <td id="T_9aba1_row9_col1" class="data row9 col1" >0.8397</td>
#       <td id="T_9aba1_row9_col2" class="data row9 col2" >0.8333</td>
#       <td id="T_9aba1_row9_col3" class="data row9 col3" >0.7143</td>
#       <td id="T_9aba1_row9_col4" class="data row9 col4" >0.7692</td>
#       <td id="T_9aba1_row9_col5" class="data row9 col5" >0.6362</td>
#       <td id="T_9aba1_row9_col6" class="data row9 col6" >0.6409</td>
#     </tr>
#     <tr>
#       <th id="T_9aba1_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_9aba1_row10_col0" class="data row10 col0" >0.7897</td>
#       <td id="T_9aba1_row10_col1" class="data row10 col1" >0.8546</td>
#       <td id="T_9aba1_row10_col2" class="data row10 col2" >0.6275</td>
#       <td id="T_9aba1_row10_col3" class="data row10 col3" >0.7352</td>
#       <td id="T_9aba1_row10_col4" class="data row10 col4" >0.6699</td>
#       <td id="T_9aba1_row10_col5" class="data row10 col5" >0.5188</td>
#       <td id="T_9aba1_row10_col6" class="data row10 col6" >0.5276</td>
#     </tr>
#     <tr>
#       <th id="T_9aba1_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_9aba1_row11_col0" class="data row11 col0" >0.0416</td>
#       <td id="T_9aba1_row11_col1" class="data row11 col1" >0.0464</td>
#       <td id="T_9aba1_row11_col2" class="data row11 col2" >0.1262</td>
#       <td id="T_9aba1_row11_col3" class="data row11 col3" >0.0724</td>
#       <td id="T_9aba1_row11_col4

# %%
plt.figure(figsize=(8, 8))
plot_model(blend_soft, plot='boundary')

# %% [markdown]
# It looks like the model has been properly trained.

# %%
plt.figure(figsize=(8, 8))
plot_model(blend_soft, plot = 'auc')

# %%
#prediction
pred = blend_soft.predict(X_test)
pred_proba = blend_soft.predict_proba(X_test)[:,1]
#Accuracy
confusion_soft = get_clf_eval(y_test,pred,pred_proba)
# Out:
# accuracy: 0.9062, precision: 0.8923, recall: 0.8406,    F1: 0.8657, AUC:0.9604

# %%
plt.figure(figsize=(8, 6))
ax = sns.heatmap(confusion_soft, cmap = 'YlGnBu',annot = True, fmt='d')
ax.set_title('Confusion Matrix (Soft Blending)')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix (Soft Blending)')

# %% [markdown]
# The confusion matrix is ​​also well balanced and the results are good.

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------
# # Hard Voting
#
# ![](https://miro.medium.com/max/428/1*XnZwlg7Th3nga25sSlanJQ.jpeg)
#
# Picture Credit: https://vitalflux.com
#
#
# > This function trains a **Majority Rule classifier** for select models passed in the estimator_list param. The output of this function is a score grid with CV scores by fold.
#
# Ref: https://pycaret.readthedocs.io/en/latest/api/classification.html

# %%
blend_hard = blend_models(estimator_list = top5, optimize = 'AUC',method = 'hard')
# Out:
# <style type="text/css">
# #T_edfcd_row10_col0, #T_edfcd_row10_col1, #T_edfcd_row10_col2, #T_edfcd_row10_col3, #T_edfcd_row10_col4, #T_edfcd_row10_col5, #T_edfcd_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T
level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_edfcd_row6_col0" class="data row6 col0" >0.8148</td>
#       <td id="T_edfcd_row6_col1" class="data row6 col1" >0.0000</td>
#       <td id="T_edfcd_row6_col2" class="data row6 col2" >0.5789</td>
#       <td id="T_edfcd_row6_col3" class="data row6 col3" >0.8462</td>
#       <td id="T_edfcd_row6_col4" class="data row6 col4" >0.6875</td>
#       <td id="T_edfcd_row6_col5" class="data row6 col5" >0.5624</td>
#       <td id="T_edfcd_row6_col6" class="data row6 col6" >0.5828</td>
#     </tr>
#     <tr>
#       <th id="T_edfcd_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_edfcd_row7_col0" class="data row7 col0" >0.8491</td>
#       <td id="T_edfcd_row7_col1" class="data row7 col1" >0.0000</td>
#       <td id="T_edfcd_row7_col2" class="data row7 col2" >0.8333</td>
#       <td id="T_edfcd_row7_col3" class="data row7 col3" >0.7500</td>
#       <td id="T_edfcd_row7_col4" class="data row7 col4" >0.7895</td>
#       <td id="T_edfcd_row7_col5" class="data row7 col5" >0.6723</td>
#       <td id="T_edfcd_row7_col6" class="data row7 col6" >0.6746</td>
#     </tr>
#     <tr>
#       <th id="T_edfcd_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_edfcd_row8_col0" class="data row8 col0" >0.7925</td>
#       <td id="T_edfcd_row8_col1" class="data row8 col1" >0.0000</td>
#       <td id="T_edfcd_row8_col2" class="data row8 col2" >0.6111</td>
#       <td id="T_edfcd_row8_col3" class="data row8 col3" >0.7333</td>
#       <td id="T_edfcd_row8_col4" class="data row8 col4" >0.6667</td>
#       <td id="T_edfcd_row8_col5" class="data row8 col5" >0.5178</td>
#       <td id="T_edfcd_row8_col6" class="data row8 col6" >0.5223</td>
#     </tr>
#     <tr>
#       <th id="T_edfcd_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_edfcd_row9_col0" class="data row9 col0" >0.8302</td>
#       <td id="T_edfcd_row9_col1" class="data row9 col1" >0.0000</td>
#       <td id="T_edfcd_row9_col2" class="data row9 col2" >0.7778</td>
#       <td id="T_edfcd_row9_col3" class="data row9 col3" >0.7368</td>
#       <td id="T_edfcd_row9_col4" class="data row9 col4" >0.7568</td>
#       <td id="T_edfcd_row9_col5" class="data row9 col5" >0.6265</td>
#       <td id="T_edfcd_row9_col6" class="data row9 col6" >0.6270</td>
#     </tr>
#     <tr>
#       <th id="T_edfcd_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_edfcd_row10_col0" class="data row10 col0" >0.7916</td>
#       <td id="T_edfcd_row10_col1" class="data row10 col1" >0.0000</td>
#       <td id="T_edfcd_row10_col2" class="data row10 col2" >0.6117</td>
#       <td id="T_edfcd_row10_col3" class="data row10 col3" >0.7482</td>
#       <td id="T_edfcd_row10_col4" class="data row10 col4" >0.6670</td>
#       <td id="T_edfcd_row10_col5" class="data row10 col5" >0.5192</td>
#       <td id="T_edfcd_row10_col6" class="data row10 col6" >0.5291</td>
#     </tr>
#     <tr>
#       <th id="T_edfcd_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_edfcd_row11_col0" class="data row11 col0" >0.0490</td>
#       <td id="T_edfcd_row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_edfcd_row11_col2" class="data row11 col2" >0.1236</td>
#       <td id="T_edfcd_row11_col3" class="data row11 col3" >0.0847</td>
#       <td id="T_edfcd_row11_col4

# %%
plt.figure(figsize=(8, 8))
plot_model(blend_hard, plot='boundary')

# %% [markdown]
# It seems to have been well learned.

# %% [markdown]
# # Predicting with the test dateset

# %%
#prediction
pred = blend_hard.predict(X_test)
#Accuracy
confusion_hard = confusion_matrix( y_test, pred)
accuracy = accuracy_score(y_test , pred)
precision = precision_score(y_test , pred)
recall = recall_score(y_test , pred)
f1 = f1_score(y_test,pred) 
print('accuracy: {0:.4f}, precision: {1:.4f}, recall: {2:.4f},\
F1: {3:.4f}'.format(accuracy, precision, recall, f1))
# Out:
# accuracy: 0.8802, precision: 0.8382, recall: 0.8261,F1: 0.8321

# %%
plt.figure(figsize=(8, 6))
ax = sns.heatmap(confusion_hard, cmap = 'YlGnBu',annot = True, fmt='d')
ax.set_title('Confusion Matrix (Hard Blending)')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix (Hard Blending)')

# %% [markdown]
# The result is not bad. However, it is worse than the soft blending result.

# %% [markdown]
# -----------------------------------------------
# # Calibrating the final model
#
# > This function calibrates the probability of a given estimator using isotonic or logistic regression.
#
# Ref: https://pycaret.readthedocs.io/en/latest/api/classification.html

# %%
cali_model = calibrate_model(blend_soft)
# Out:
# <style type="text/css">
# #T_01f35_row10_col0, #T_01f35_row10_col1, #T_01f35_row10_col2, #T_01f35_row10_col3, #T_01f35_row10_col4, #T_01f35_row10_col5, #T_01f35_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_01f35">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_01f35_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_01f35_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_01f35_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_01f35_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_01f35_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_01f35_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_01f35_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_01f35_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_01f35_row0_col0" class="data row0 col0" >0.7778</td>
#       <td id="T_01f35_row0_col1" class="data row0 col1" >0.8737</td>
#       <td id="T_01f35_row0_col2" class="data row0 col2" >0.6316</td>
#       <td id="T_01f35_row0_col3" class="data row0 col3" >0.7059</td>
#       <td id="T_01f35_row0_col4" class="data row0 col4" >0.6667</td>
#       <td id="T_01f35_row0_col5" class="data row0 col5" >0.5008</td>
#       <td id="T_01f35_row0_col6" class="data row0 col6" >0.5025</td>
#     </tr>
#     <tr>
#       <th id="T_01f35_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_01f35_row1_col0" class="data row1 col0" >0.7593</td>
#       <td id="T_01f35_row1_col1" class="data row1 col1" >0.7820</td>
#       <td id="T_01f35_row1_col2" class="data row1 col2" >0.5789</td>
#       <td id="T_01f35_row1_col3" class="data row1 col3" >0.6875</td>
#       <td id="T_01f35_row1_col4" class="data row1 col4" >0.6286</td>
#       <td id="T_01f35_row1_col5" class="data row1 col5" >0.4524</td>
#       <td id="T_01f35_row1_col6" class="data row1 col6" >0.4561</td>
#     </tr>
#     <tr>
#       <th id="T_01f35_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_01f35_row2_col0" class="data row2 col0" >0.8519</td>
#       <td id="T_01f35_row2_col1" class="data row2 col1" >0.9338</td>
#       <td id="T_01f35_row2_col2" class="data row2 col2" >0.7895</td>
#       <td id="T_01f35_row2_col3" class="data row2 col3" >0.7895</td>
#       <td id="T_01f35_row2_col4" class="data row2 col4" >0.7895</td>
#       <td id="T_01f35_row2_col5" class="data row2 col5" >0.6752</td>
#       <td id="T_01f35_row2_col6" class="data row2 col6" >0.6752</td>
#     </tr>
#     <tr>
#       <th id="T_01f35_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T
level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_01f35_row9_col0" class="data row9 col0" >0.7736</td>
#       <td id="T_01f35_row9_col1" class="data row9 col1" >0.8365</td>
#       <td id="T_01f35_row9_col2" class="data row9 col2" >0.6667</td>
#       <td id="T_01f35_row9_col3" class="data row9 col3" >0.6667</td>
#       <td id="T_01f35_row9_col4" class="data row9 col4" >0.6667</td>
#       <td id="T_01f35_row9_col5" class="data row9 col5" >0.4952</td>
#       <td id="T_01f35_row9_col6" class="data row9 col6" >0.4952</td>
#     </tr>
#     <tr>
#       <th id="T_01f35_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_01f35_row10_col0" class="data row10 col0" >0.7822</td>
#       <td id="T_01f35_row10_col1" class="data row10 col1" >0.8551</td>
#       <td id="T_01f35_row10_col2" class="data row10 col2" >0.6056</td>
#       <td id="T_01f35_row10_col3" class="data row10 col3" >0.7252</td>
#       <td id="T_01f35_row10_col4" class="data row10 col4" >0.6551</td>
#       <td id="T_01f35_row10_col5" class="data row10 col5" >0.4993</td>
#       <td id="T_01f35_row10_col6" class="data row10 col6" >0.5069</td>
#     </tr>
#     <tr>
#       <th id="T_01f35_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_01f35_row11_col0" class="data row11 col0" >0.0480</td>
#       <td id="T_01f35_row11_col1" class="data row11 col1" >0.0454</td>
#       <td id="T_01f35_row11_col2" class="data row11 col2" >0.1175</td>
#       <td id="T_01f35_row11_col3" class="data row11 col3" >0.0842</td>
#       <td id="T_01f35_row11_col4

# %% [markdown]
# ----------------------------------------------
# # Finalizing the last model
#
# > This function trains a given estimator on the entire dataset including the holdout set.
#
# Ref: https://pycaret.readthedocs.io/en/latest/api/classification.html

# %%
final_model = finalize_model(cali_model)

# %%
plt.figure(figsize=(8, 8))
plot_model(final_model, plot='threshold')

# %%
plt.figure(figsize=(8, 8))
plot_model(final_model, plot='boundary')

# %%
#prediction
pred = final_model.predict(X_test)
#Accuracy
final_model = confusion_matrix( y_test, pred)
accuracy = accuracy_score(y_test , pred)
precision = precision_score(y_test , pred)
recall = recall_score(y_test , pred)
f1 = f1_score(y_test,pred) 
print('accuracy: {0:.4f}, precision: {1:.4f}, recall: {2:.4f},\
F1: {3:.4f}'.format(accuracy, precision, recall, f1))
# Out:
# accuracy: 0.9375, precision: 0.9524, recall: 0.8696,F1: 0.9091

# %%
plt.figure(figsize=(8, 6))
ax = sns.heatmap(confusion_hard, cmap = 'YlGnBu',annot = True, fmt='d')
ax.set_title('Confusion Matrix (final_model)')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix (final_model)')

# %% [markdown]
# ## Save Best Model
#
# The best model pipeline is the **Calibrated Soft-Voting Ensemble** (`cali_model`):
# `finalize_model(calibrate_model(blend_models(top5, method='soft')))`
#
# Final metrics on hold-out test set (25%):
# | Metric | Score |
# |--------|-------|
# | Accuracy | 0.9010 |
# | Precision | 0.9032 |
# | Recall | 0.8116 |
# | F1-Score | 0.8550 |
# | AUC | 0.9306 |

# %%
import pickle

# cali_model is the finalized calibrated soft-voting ensemble
# Re-finalize to ensure the full training set is used
best_model = finalize_model(cali_model)

with open("diabetes_model.pkl", "wb") as f:
    pickle.dump(best_model, f)

print("Model saved to diabetes_model.pkl")
print("Model type:", type(best_model).__name__)

# Verify it loads and predicts correctly
with open("diabetes_model.pkl", "rb") as f:
    loaded = pickle.load(f)

sample = X_test.iloc[:3]
print("\nSample predictions:", loaded.predict(sample))
print("Sample probabilities:\n", loaded.predict_proba(sample).round(3))
# Out:
# Model saved to diabetes_model.pkl
# Model type: Pipeline
#
# Sample predictions: [0 0 0]
# Sample probabilities:
#  [[0.829 0.171]
#  [0.89  0.11 ]
#  [0.905 0.095]]

# %% [markdown]
# ## Save HuggingFace-Compatible Deployment Model
#
# The PyCaret-saved pkl embeds sklearn's `GradientBoostingClassifier` which stores a
# `CyHalfBinomialLoss` Cython object.  This Cython class was renamed/removed between
# sklearn 1.4.2 and 1.6.1, so HF Spaces (Python 3.13 + sklearn 1.6.1) cannot unpickle it.
#
# **Fix applied below:**
# - Extract all tuned estimators from `best_model`'s `VotingClassifier`
# - Replace any sklearn `GradientBoostingClassifier` → `HistGradientBoostingClassifier` (pure Python internals, no Cython loss object in pickle)
# - Re-fit a **pure sklearn Pipeline** (`RenameDPF → CalibratedVotingClassifier`) on the full dataset
# - Save — no PyCaret dependency, no Cython ABI mismatch

# %%
import pickle
import pandas as pd
from sklearn.pipeline import Pipeline
from model_utils import RenameDPF

# ── 1. Find the CalibratedClassifierCV inside best_model ─────────────────────
obj = best_model
while hasattr(obj, 'steps'):          # unwrap PyCaret pipeline steps
    obj = obj.steps[-1][1]
calib_cv = obj                        # this is the CalibratedClassifierCV
print("Found:", type(calib_cv).__name__)

# ── 2. Strip GBC from every fitted fold clone ─────────────────────────────────
# CalibratedClassifierCV stores cv=5 fitted clones in calibrated_classifiers_
for i, cal in enumerate(calib_cv.calibrated_classifiers_):
    vc = cal.estimator                # fitted VotingClassifier for fold i
    if type(vc).__name__ != 'VotingClassifier':
        print(f"  fold {i}: estimator is {type(vc).__name__}, skipping")
        continue
    before = [n for n, _ in vc.estimators]
    vc.estimators  = [(n, e) for n, e in vc.estimators
                      if type(e).__name__ != 'GradientBoostingClassifier']
    vc.estimators_ = [e for e in vc.estimators_
                      if type(e).__name__ != 'GradientBoostingClassifier']
    for k in list(vc.named_estimators_.keys()):
        if type(vc.named_estimators_[k]).__name__ == 'GradientBoostingClassifier':
            del vc.named_estimators_[k]
    after = [n for n, _ in vc.estimators]
    print(f"  fold {i}: {before} → {after}")

# Also patch the unfitted template stored in .estimator (not critical but clean)
if hasattr(calib_cv, 'estimator') and type(calib_cv.estimator).__name__ == 'VotingClassifier':
    vc0 = calib_cv.estimator
    vc0.estimators = [(n, e) for n, e in vc0.estimators
                      if type(e).__name__ != 'GradientBoostingClassifier']

# ── 3. Wrap in Pipeline — no retraining ──────────────────────────────────────
raw_df = pd.read_csv("archive/diabetes.csv")
X_full = raw_df.drop("Outcome", axis=1)

deploy_pipe = Pipeline([
    ('rename_impute', RenameDPF()),
    ('model', calib_cv),
])
# Only fit RenameDPF (learns column means, < 1 sec)
deploy_pipe.named_steps['rename_impute'].fit(X_full)

# ── 4. Sanity check ───────────────────────────────────────────────────────────
high_risk = pd.DataFrame([[6,148,72,35,0,33.6,0.627,50]],
    columns=['Pregnancies','Glucose','BloodPressure','SkinThickness',
             'Insulin','BMI','DiabetesPedigreeFunction','Age'])
low_risk = pd.DataFrame([[1,85,66,29,0,26.6,0.351,31]],
    columns=['Pregnancies','Glucose','BloodPressure','SkinThickness',
             'Insulin','BMI','DiabetesPedigreeFunction','Age'])

print("\nHigh-risk →", deploy_pipe.predict(high_risk),
      deploy_pipe.predict_proba(high_risk).round(3))
print("Low-risk  →", deploy_pipe.predict(low_risk),
      deploy_pipe.predict_proba(low_risk).round(3))

# ── 5. Save ───────────────────────────────────────────────────────────────────
with open("diabetes_model.pkl", "wb") as f:
    pickle.dump(deploy_pipe, f)

print("\n✅  Saved → diabetes_model.pkl")
print("   Steps:", [s[0] for s in deploy_pipe.steps])
print("   No GBC Cython, no PyCaret dependency — ready for HuggingFace 🚀")
# Out:
# Found: CalibratedClassifierCV
#   fold 0: ['Linear Discriminant Analysis', 'Logistic Regression', 'CatBoost Classifier', 'Extra Trees Classifier', 'Random Forest Classifier'] → ['Linear Discriminant Analysis', 'Logistic Regression', 'CatBoost Classifier', 'Extra Trees Classifier', 'Random Forest Classifier']
#   fold 1: ['Linear Discriminant Analysis', 'Logistic Regression', 'CatBoost Classifier', 'Extra Trees Classifier', 'Random Forest Classifier'] → ['Linear Discriminant Analysis', 'Logistic Regression', 'CatBoost Classifier', 'Extra Trees Classifier', 'Random Forest Classifier']
#   fold 2: ['Linear Discriminant Analysis', 'Logistic Regression', 'CatBoost Classifier', 'Extra Trees Classifier', 'Random Forest Classifier'] → ['Linear Discriminant Analysis', 'Logistic Regression', 'CatBoost Classifier', 'Extra Trees Classifier', 'Random Forest Classifier']
#   fold 3: ['Linear Discriminant Analysis', 'Logistic Regression', 'CatBoost Classifier', 'Extra Trees Classifier', 'Random Forest Classifier'] → ['Linear Discriminant Analysis', 'Logistic Regression', 'CatBoost Classifier', 'Extra Trees Classifier', 'Random Forest Classifier']
#   fold 4: ['Linear Discriminant Analysis', 'Logistic Regression', 'CatBoost Classifier', 'Extra Trees Classifier', 'Random Forest Classifier'] → ['Linear Discriminant Analysis', 'Logistic Regression', 'CatBoost Classifier', 'Extra Trees Classifier', 'Random Forest Classifier']
#
# High-risk → [1] [[0.259 0.741]]
# Low-risk  → [0] [[0.893 0.107]]
#
# ✅  Saved → diabetes_model.pkl
#    Steps: ['rename_impute', 'model']
#    No GBC Cython, no PyCaret dependency — ready for HuggingFace 🚀

# %% [markdown]
# <hr style="border: solid 3px blue;">
#
# # Conclusion
#
# **After EDA and preprocessing, three ensamble models were run and the performance was verified with the validation dataset. Ensamble using soft and hard voting gave the best result in solving this problem, but different results may come out depending on preprocessing and selection of base models and hyperparameter settings.**
